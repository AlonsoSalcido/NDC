# %%
import pandas as pd
from pandas import json_normalize
import json
import pyodbc

# %%
# Open the file
with open('C:/Users/Alonso/Downloads/ndc/drug-ndc-0001-of-0001/drug-ndc-0001-of-0001.json', 'r') as json_file:
    # Load the JSON data from the file
    original_data = json.load(json_file)

# %%
data=original_data
data
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#   'terms': 'https://open.fda.gov/terms/',
#   'license': 'https://open.fda.gov/license/',
#   'last_updated': '2023-02-28',
#   'results': {'skip': 0, 'limit': 124248, 'total': 124248}},
#  'results': [{'product_ndc': '77006-013',
#    'generic_name': 'ALCOHOL',
#    'labeler_name': 'WeCool Toys, Inc.',
#    'brand_name': 'Crazy Clean Hand Sanitizer - Berry Swirl',
#    'active_ingredients': [{'name': 'ALCOHOL', 'strength': '58.36 g/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77006-013-01',
#      'description': '30 mL in 1 BOTTLE (77006-013-01)',
#      'marketing_start_date': '20200330',
#      'sample': False},
#     {'package_ndc': '77006-013-02',
#      'description': '249 mL in 1 BOTTLE, PUMP (77006-013-02)',
#      'marketing_start_date': '20200330',
#      'sample': False},
#     {'package_ndc': '77006-013-03',
#      'description': '60 mL in 1 BOTTLE (77006-013-03)',
#      'marketing_start_date': '20200330',
#      'sample': False},
#     {'package_ndc': '77006-013-04',
#      'description': '975 mL in 1 BOTTLE, PUMP (77006-013-04)',
#      'marketing_start_date': '20200723',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['WeCool Toys, Inc.'],
#     'spl_set_id': ['a6a6b2ae-6fb8-7793-e053-2995a90a2a69'],
#     'is_original_packager': [True],
#     'unii': ['3K9958V90M']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'LIQUID',
#    'spl_id': 'd5660475-f5c5-c05b-e053-2995a90a6fd4',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200330',
#    'product_id': '77006-013_d5660475-f5c5-c05b-e053-2995a90a6fd4',
#    'application_number': 'part333A',
#    'brand_name_base': 'Crazy Clean Hand Sanitizer - Berry Swirl'},
#   {'product_ndc': '77006-034',
#    'generic_name': 'Alcohol',
#    'labeler_name': 'WeCool Toys',
#    'brand_name': 'We Clean Hand Sanitizer Caramel Apple',
#    'active_ingredients': [{'name': 'ALCOHOL', 'strength': '58.36 g/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77006-034-01',
#      'description': '250 mL in 1 BOTTLE, PUMP (77006-034-01)',
#      'marketing_start_date': '20200626',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['WeCool Toys'],
#     'spl_set_id': ['aa93f1dd-b13b-3ba7-e053-2a95a90a5a02'],
#     'is_original_packager': [True],
#     'upc': ['0760939631897'],
#     'unii': ['3K9958V90M']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'LIQUID',
#    'spl_id': 'd567d693-9dfb-f51a-e053-2995a90a304b',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200626',
#    'product_id': '77006-034_d567d693-9dfb-f51a-e053-2995a90a304b',
#    'application_number': 'part333A',
#    'brand_name_base': 'We Clean Hand Sanitizer Caramel Apple'},
#   {'product_ndc': '77027-112',
#    'generic_name': 'ALCOHOL',
#    'labeler_name': 'GUANGZHOU ZUOFUN COSMETICS CO., LTD.',
#    'brand_name': 'Anti-Bacterial Hand Sanitizer',
#    'active_ingredients': [{'name': 'ALCOHOL', 'strength': '75 mL/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77027-112-01',
#      'description': '60 mL in 1 BOTTLE, PLASTIC (77027-112-01)',
#      'marketing_start_date': '20201221',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['GUANGZHOU ZUOFUN COSMETICS CO., LTD.'],
#     'spl_set_id': ['baf26dc0-1cc0-4cd8-99df-bf9234f443bf'],
#     'is_original_packager': [True],
#     'unii': ['3K9958V90M']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'GEL',
#    'spl_id': 'b82dfc94-73dc-1aa6-e053-2995a90a30d5',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20201221',
#    'product_id': '77027-112_b82dfc94-73dc-1aa6-e053-2995a90a30d5',
#    'application_number': 'part333A',
#    'brand_name_base': 'Anti-Bacterial Hand Sanitizer'},
#   {'product_ndc': '77049-0012',
#    'generic_name': 'niacinamide, adenosine',
#    'labeler_name': 'Interkos Co.,Ltd.',
#    'brand_name': 'The Fact Natural SFN 18 Skin Toner',
#    'active_ingredients': [{'name': 'ADENOSINE', 'strength': '.04 g/100mL'},
#     {'name': 'NIACINAMIDE', 'strength': '2 g/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77049-0012-1',
#      'description': '150 mL in 1 BOTTLE (77049-0012-1)',
#      'marketing_start_date': '20220121',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['Interkos Co.,Ltd.'],
#     'spl_set_id': ['d610a3ca-ac46-2835-e053-2995a90a5ad9'],
#     'is_original_packager': [True],
#     'nui': ['N0000178375', 'N0000175788'],
#     'pharm_class_epc': ['Adenosine Receptor Agonist [EPC]'],
#     'pharm_class_moa': ['Adenosine Receptor Agonists [MoA]'],
#     'unii': ['K72T3FS567', '25X51I8RD4']},
#    'marketing_category': 'UNAPPROVED DRUG OTHER',
#    'dosage_form': 'LIQUID',
#    'spl_id': 'd610a3ca-ac45-2835-e053-2995a90a5ad9',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20220121',
#    'product_id': '77049-0012_d610a3ca-ac45-2835-e053-2995a90a5ad9',
#    'brand_name_base': 'The Fact Natural SFN 18 Skin Toner',
#    'pharm_class': ['Adenosine Receptor Agonist [EPC]',
#     'Adenosine Receptor Agonists [MoA]']},
#   {'product_ndc': '77052-010',
#    'generic_name': 'Hydrocortisone',
#    'labeler_name': 'Derm Ventures LLC',
#    'brand_name': 'Ala-Scalp',
#    'active_ingredients': [{'name': 'HYDROCORTISONE', 'strength': '20 mg/mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77052-010-01',
#      'description': '1 BOTTLE, WITH APPLICATOR in 1 BOX (77052-010-01)  / 29.6 mL in 1 BOTTLE, WITH APPLICATOR',
#      'marketing_start_date': '20210101',
#      'sample': False},
#     {'package_ndc': '77052-010-02',
#      'description': '1 BOTTLE, WITH APPLICATOR in 1 BOX (77052-010-02)  / 59.2 mL in 1 BOTTLE, WITH APPLICATOR',
#      'marketing_start_date': '20200724',
#      'sample': False}],
#    'listing_expiration_date': '20241231',
#    'openfda': {'manufacturer_name': ['Derm Ventures LLC'],
#     'rxcui': ['197784', '884077'],
#     'spl_set_id': ['61498a40-3b3c-4066-89c8-d99686e2d638'],
#     'is_original_packager': [True],
#     'upc': ['0377052010029'],
#     'nui': ['N0000175576', 'N0000175450'],
#     'pharm_class_epc': ['Corticosteroid [EPC]'],
#     'pharm_class_moa': ['Corticosteroid Hormone Receptor Agonists [MoA]'],
#     'unii': ['WI4X0X7BPJ']},
#    'marketing_category': 'ANDA',
#    'dosage_form': 'LOTION',
#    'spl_id': 'f1ff1093-4a24-6b56-e053-2995a90ada7f',
#    'product_type': 'HUMAN PRESCRIPTION DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200724',
#    'product_id': '77052-010_f1ff1093-4a24-6b56-e053-2995a90ada7f',
#    'application_number': 'ANDA083231',
#    'brand_name_base': 'Ala-Scalp',
#    'pharm_class': ['Corticosteroid Hormone Receptor Agonists [MoA]',
#     'Corticosteroid [EPC]']},
#   {'product_ndc': '77071-006',
#    'generic_name': 'BENZALKONIUM CHLORIDE',
#    'labeler_name': 'Dalrada Health Products',
#    'brand_name': 'glanHealth Hand Sanitizer Professional',
#    'active_ingredients': [{'name': 'BENZALKONIUM CHLORIDE',
#      'strength': '1.3 mg/mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77071-006-00',
#      'description': '1200 mL in 1 BAG (77071-006-00)',
#      'marketing_start_date': '20200101',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['Dalrada Health Products'],
#     'rxcui': ['1049254'],
#     'spl_set_id': ['1dbb3ee4-40ff-4d4b-a263-023b5bbf4201'],
#     'is_original_packager': [True],
#     'upc': ['0810001570637'],
#     'unii': ['F5UM2KM3W7']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'SOAP',
#    'spl_id': 'acd6ce36-46f5-5468-e053-2a95a90a72db',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200101',
#    'product_id': '77071-006_acd6ce36-46f5-5468-e053-2a95a90a72db',
#    'application_number': 'part333E',
#    'brand_name_base': 'glanHealth Hand Sanitizer Professional'},
#   {'product_ndc': '0615-8354',
#    'generic_name': 'Gemfibrozil',
#    'labeler_name': 'NCS HealthCare of KY, LLC dba Vangard Labs',
#    'brand_name': 'Gemfibrozil',
#    'active_ingredients': [{'name': 'GEMFIBROZIL', 'strength': '600 mg/1'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '0615-8354-39',
#      'description': '30 TABLET, FILM COATED in 1 BLISTER PACK (0615-8354-39)',
#      'marketing_start_date': '20201110',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['NCS HealthCare of KY, LLC dba Vangard Labs'],
#     'rxcui': ['310459'],
#     'spl_set_id': ['394dfb45-cd3c-4e1e-8dd6-7e4867e90a03'],
#     'nui': ['N0000175596', 'N0000175375', 'M0199111'],
#     'pharm_class_epc': ['Peroxisome Proliferator Receptor alpha Agonist [EPC]'],
#     'pharm_class_moa': ['Peroxisome Proliferator-activated Receptor alpha Agonists [MoA]'],
#     'pharm_class_cs': ['PPAR alpha [CS]'],
#     'unii': ['Q8X02027X3']},
#    'marketing_category': 'ANDA',
#    'dosage_form': 'TABLET, FILM COATED',
#    'spl_id': '41a6e05c-7bec-43e1-803c-e600dce780fc',
#    'product_type': 'HUMAN PRESCRIPTION DRUG',
#    'route': ['ORAL'],
#    'marketing_start_date': '20150916',
#    'product_id': '0615-8354_41a6e05c-7bec-43e1-803c-e600dce780fc',
#    'application_number': 'ANDA202726',
#    'brand_name_base': 'Gemfibrozil',
#    'pharm_class': ['PPAR alpha [CS]',
#     'Peroxisome Proliferator Receptor alpha Agonist [EPC]',
#     'Peroxisome Proliferator-activated Receptor alpha Agonists [MoA]']},
#   {'product_ndc': '77093-222',
#    'generic_name': 'IPA Hand Sanitizer',
#    'labeler_name': 'Vincit Zee Company',
#    'brand_name': 'LS32',
#    'active_ingredients': [{'name': 'ISOPROPYL ALCOHOL',
#      'strength': '70 mL/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77093-222-01',
#      'description': '236.59 mL in 1 BOTTLE, PLASTIC (77093-222-01)',
#      'marketing_start_date': '20200519',
#      'sample': False},
#     {'package_ndc': '77093-222-02',
#      'description': '473.18 mL in 1 BOTTLE, PLASTIC (77093-222-02)',
#      'marketing_start_date': '20200519',
#      'sample': False},
#     {'package_ndc': '77093-222-03',
#      'description': '3785 mL in 1 BOTTLE, PLASTIC (77093-222-03)',
#      'marketing_start_date': '20200519',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['Vincit Zee Company'],
#     'rxcui': ['808520'],
#     'spl_set_id': ['a61904f7-44fb-b937-e053-2995a90a7009'],
#     'is_original_packager': [True],
#     'unii': ['ND2M416302']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'LIQUID',
#    'spl_id': 'a6195a10-0199-5e0a-e053-2a95a90a1c5d',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200519',
#    'product_id': '77093-222_a6195a10-0199-5e0a-e053-2a95a90a1c5d',
#    'application_number': 'part333A',
#    'brand_name_base': 'LS32'},
#   {'product_ndc': '77130-0002',
#    'generic_name': 'sodium chlorite, citric cid',
#    'labeler_name': 'Sejin E&P Co., Ltd.',
#    'brand_name': 'AV100',
#    'active_ingredients': [{'name': 'CITRIC ACID MONOHYDRATE',
#      'strength': '.06 g/100g'},
#     {'name': 'SODIUM CHLORITE', 'strength': '.05 g/100g'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77130-0002-1',
#      'description': '4 g in 1 PACKAGE (77130-0002-1)',
#      'marketing_start_date': '20200502',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['Sejin E&P Co., Ltd.'],
#     'spl_set_id': ['a4a1883f-37b2-4857-e053-2a95a90a9031'],
#     'is_original_packager': [True],
#     'unii': ['2968PHW8QP', 'G538EBV4VF']},
#    'marketing_category': 'UNAPPROVED DRUG OTHER',
#    'dosage_form': 'POWDER',
#    'spl_id': 'd8412b61-f8d0-d331-e053-2995a90a1aa4',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200502',
#    'product_id': '77130-0002_d8412b61-f8d0-d331-e053-2995a90a1aa4',
#    'brand_name_base': 'AV100',
#    'pharm_class': ['Acidifying Activity [MoA]',
#     'Anti-coagulant [EPC]',
#     'Calcium Chelating Activity [MoA]',
#     'Calculi Dissolution Agent [EPC]',
#     'Decreased Coagulation Factor Activity [PE]']},
#   {'product_ndc': '77133-001',
#    'generic_name': 'ALCOHOL',
#    'labeler_name': 'ALCOVE BRANDS',
#    'brand_name': 'Fight wipes',
#    'active_ingredients': [{'name': 'ALCOHOL', 'strength': '.75 mL/mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77133-001-01',
#      'description': '20 PATCH in 1 BAG (77133-001-01)  / 4 mL in 1 PATCH',
#      'marketing_start_date': '20201224',
#      'sample': False},
#     {'package_ndc': '77133-001-02',
#      'description': '50 PATCH in 1 BAG (77133-001-02)  / 4 mL in 1 PATCH',
#      'marketing_start_date': '20201224',
#      'sample': False},
#     {'package_ndc': '77133-001-03',
#      'description': '50 PACKET in 1 BOX (77133-001-03)  / 1 PATCH in 1 PACKET / 3 mL in 1 PATCH',
#      'marketing_start_date': '20201224',
#      'sample': False}],
#    'listing_expiration_date': '20241231',
#    'openfda': {'manufacturer_name': ['ALCOVE BRANDS'],
#     'rxcui': ['1307051'],
#     'spl_set_id': ['b4513a44-c0e0-3558-e053-2995a90ae01b'],
#     'is_original_packager': [True],
#     'upc': ['0850015109089'],
#     'unii': ['3K9958V90M']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'CLOTH',
#    'spl_id': 'd816804a-5165-538d-e053-2995a90a2b75',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20201224',
#    'product_id': '77133-001_d816804a-5165-538d-e053-2995a90a2b75',
#    'application_number': 'part333E',
#    'brand_name_base': 'Fight wipes'},
#   {'product_ndc': '77175-005',
#    'marketing_end_date': '20230401',
#    'generic_name': 'Ethanol alcohol',
#    'labeler_name': 'TenSan',
#    'brand_name': 'Hand Sanitizer Liquid',
#    'active_ingredients': [{'name': 'ALCOHOL',
#      'strength': '817.56 L/1021.95L'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77175-005-02',
#      'description': '1022 L in 1 TANK (77175-005-02)',
#      'marketing_start_date': '20200501',
#      'marketing_end_date': '20230401',
#      'sample': False}],
#    'openfda': {'manufacturer_name': ['TenSan'],
#     'rxcui': ['581662', '1039339'],
#     'spl_set_id': ['a487004b-a591-4b71-e053-2995a90ac8be'],
#     'is_original_packager': [True],
#     'unii': ['3K9958V90M']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'LIQUID',
#    'spl_id': 'c8aed3a0-e55e-7baf-e053-2995a90a259b',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200401',
#    'product_id': '77175-005_c8aed3a0-e55e-7baf-e053-2995a90a259b',
#    'application_number': 'part333A',
#    'brand_name_base': 'Hand Sanitizer Liquid'},
#   {'product_ndc': '77175-008',
#    'marketing_end_date': '20230818',
#    'generic_name': 'ALCOHOL (Ethanol)',
#    'labeler_name': 'TenSan',
#    'brand_name': 'Hand Sanitizer Gel',
#    'active_ingredients': [{'name': 'ALCOHOL', 'strength': '715.4 L/1021.95L'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77175-008-01',
#      'description': '1022 L in 1 TANK (77175-008-01)',
#      'marketing_start_date': '20200818',
#      'marketing_end_date': '20230818',
#      'sample': False}],
#    'openfda': {'manufacturer_name': ['TenSan'],
#     'rxcui': ['581662', '1039339'],
#     'spl_set_id': ['a487004b-a591-4b71-e053-2995a90ac8be'],
#     'is_original_packager': [True],
#     'unii': ['3K9958V90M']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'GEL',
#    'spl_id': 'c8aed3a0-e55e-7baf-e053-2995a90a259b',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200818',
#    'product_id': '77175-008_c8aed3a0-e55e-7baf-e053-2995a90a259b',
#    'application_number': 'part333A',
#    'brand_name_base': 'Hand Sanitizer Gel'},
#   {'product_ndc': '0615-8359',
#    'generic_name': 'Paroxetine',
#    'labeler_name': 'NCS HealthCare of KY, LLC dba Vangard Labs',
#    'brand_name': 'Paroxetine',
#    'active_ingredients': [{'name': 'PAROXETINE HYDROCHLORIDE',
#      'strength': '10 mg/1'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '0615-8359-39',
#      'description': '30 TABLET, FILM COATED in 1 BLISTER PACK (0615-8359-39)',
#      'marketing_start_date': '20201111',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['NCS HealthCare of KY, LLC dba Vangard Labs'],
#     'rxcui': ['1738483'],
#     'spl_set_id': ['0a8a58c7-5008-4c65-ae0e-e4ee809b1807'],
#     'unii': ['X2ELS050D8']},
#    'marketing_category': 'ANDA',
#    'dosage_form': 'TABLET, FILM COATED',
#    'spl_id': 'd04ea3ee-ed50-48ca-8226-fb2d029053f3',
#    'product_type': 'HUMAN PRESCRIPTION DRUG',
#    'route': ['ORAL'],
#    'marketing_start_date': '20091203',
#    'product_id': '0615-8359_d04ea3ee-ed50-48ca-8226-fb2d029053f3',
#    'application_number': 'ANDA078406',
#    'brand_name_base': 'Paroxetine',
#    'pharm_class': ['Serotonin Reuptake Inhibitor [EPC]',
#     'Serotonin Uptake Inhibitors [MoA]']},
#   {'product_ndc': '77251-002',
#    'generic_name': 'Disinfectant Cleaning Wipes',
#    'labeler_name': 'QUIMICA ROSMAR S.A. DE C.V.',
#    'brand_name': 'Sanidry Wipes',
#    'active_ingredients': [{'name': 'BENZALKONIUM CHLORIDE',
#      'strength': '.133 1/1001'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77251-002-01',
#      'description': '300 CLOTH in 1 PACKAGE (77251-002-01)',
#      'marketing_start_date': '20200528',
#      'sample': False},
#     {'package_ndc': '77251-002-02',
#      'description': '1200 CLOTH in 1 PACKAGE (77251-002-02)',
#      'marketing_start_date': '20200528',
#      'sample': False},
#     {'package_ndc': '77251-002-03',
#      'description': '40 CLOTH in 1 BOX (77251-002-03)',
#      'marketing_start_date': '20200528',
#      'sample': False},
#     {'package_ndc': '77251-002-04',
#      'description': '100 CLOTH in 1 BAG (77251-002-04)',
#      'marketing_start_date': '20200528',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['QUIMICA ROSMAR S.A. DE C.V.'],
#     'spl_set_id': ['baceb2e1-b552-44d1-ab1b-f19e96c30f86'],
#     'is_original_packager': [True],
#     'unii': ['F5UM2KM3W7']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'CLOTH',
#    'spl_id': 'cb934de9-dbbb-1b2d-e053-2995a90a39ce',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200528',
#    'product_id': '77251-002_cb934de9-dbbb-1b2d-e053-2995a90a39ce',
#    'application_number': 'part333A',
#    'brand_name_base': 'Sanidry Wipes'},
#   {'product_ndc': '77267-004',
#    'generic_name': 'Ethyl Alcohol',
#    'labeler_name': 'Ningbo Riway Daily Commodity Co., Ltd',
#    'brand_name': 'Anti-Bacterial Hand Sanitizer Gel',
#    'active_ingredients': [{'name': 'ALCOHOL', 'strength': '75 mL/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77267-004-01',
#      'description': '30 mL in 1 BOTTLE (77267-004-01)',
#      'marketing_start_date': '20200523',
#      'sample': False},
#     {'package_ndc': '77267-004-02',
#      'description': '60 mL in 1 BOTTLE (77267-004-02)',
#      'marketing_start_date': '20200523',
#      'sample': False},
#     {'package_ndc': '77267-004-03',
#      'description': '100 mL in 1 BOTTLE (77267-004-03)',
#      'marketing_start_date': '20200523',
#      'sample': False},
#     {'package_ndc': '77267-004-04',
#      'description': '500 mL in 1 BOTTLE (77267-004-04)',
#      'marketing_start_date': '20200523',
#      'sample': False},
#     {'package_ndc': '77267-004-05',
#      'description': '1000 mL in 1 BOTTLE (77267-004-05)',
#      'marketing_start_date': '20200523',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['Ningbo Riway Daily Commodity Co., Ltd'],
#     'rxcui': ['1305100'],
#     'spl_set_id': ['a6455581-0280-48cf-e053-2995a90a26c1'],
#     'is_original_packager': [True],
#     'upc': ['6923645880339',
#      '6923645880315',
#      '6923645880292',
#      '6923645880322',
#      '6923645880308'],
#     'unii': ['3K9958V90M']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'GEL',
#    'spl_id': 'a6453052-cc39-6abd-e053-2a95a90ace5e',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200523',
#    'product_id': '77267-004_a6453052-cc39-6abd-e053-2a95a90ace5e',
#    'application_number': 'part333A',
#    'brand_name_base': 'Anti-Bacterial Hand Sanitizer Gel'},
#   {'product_ndc': '77272-002',
#    'generic_name': 'Isopropyl Alcohol',
#    'labeler_name': 'ALL BETTER CBD',
#    'brand_name': 'Hand Sanitizer',
#    'active_ingredients': [{'name': 'ISOPROPYL ALCOHOL',
#      'strength': '75 mL/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77272-002-50',
#      'description': '50 mL in 1 BOTTLE (77272-002-50)',
#      'marketing_start_date': '20200330',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['ALL BETTER CBD'],
#     'rxcui': ['2285607'],
#     'spl_set_id': ['a84cf1a3-381f-cd1b-e053-2995a90acf45'],
#     'is_original_packager': [True],
#     'unii': ['ND2M416302']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'GEL',
#    'spl_id': 'd7293f15-f3b9-8e15-e053-2995a90a842f',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200330',
#    'product_id': '77272-002_d7293f15-f3b9-8e15-e053-2995a90a842f',
#    'application_number': 'part333A',
#    'brand_name_base': 'Hand Sanitizer'},
#   {'product_ndc': '77272-004',
#    'generic_name': 'Isopropyl Alcohol',
#    'labeler_name': 'ALL BETTER CBD',
#    'brand_name': 'Hand Sanitizer',
#    'active_ingredients': [{'name': 'ISOPROPYL ALCOHOL',
#      'strength': '75 mL/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77272-004-50',
#      'description': '50 mL in 1 BOTTLE (77272-004-50)',
#      'marketing_start_date': '20200330',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['ALL BETTER CBD'],
#     'spl_set_id': ['a851a572-1873-6d2b-e053-2995a90ad9a6'],
#     'is_original_packager': [True],
#     'unii': ['ND2M416302']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'GEL',
#    'spl_id': 'd7299063-551d-594a-e053-2a95a90aff10',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200330',
#    'product_id': '77272-004_d7299063-551d-594a-e053-2a95a90aff10',
#    'application_number': 'part333A',
#    'brand_name_base': 'Hand Sanitizer'},
#   {'product_ndc': '77272-007',
#    'generic_name': 'Isopropyl Alcohol',
#    'labeler_name': 'ALL BETTER CBD',
#    'brand_name': 'Hand Sanitizer',
#    'active_ingredients': [{'name': 'ISOPROPYL ALCOHOL',
#      'strength': '75 mL/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77272-007-30',
#      'description': '30 mL in 1 BOTTLE (77272-007-30)',
#      'marketing_start_date': '20200330',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['ALL BETTER CBD'],
#     'spl_set_id': ['a85274c3-6cd1-4a13-e053-2995a90a3583'],
#     'is_original_packager': [True],
#     'unii': ['ND2M416302']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'GEL',
#    'spl_id': 'd72a4801-43f3-28c5-e053-2995a90a1a2c',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200330',
#    'product_id': '77272-007_d72a4801-43f3-28c5-e053-2995a90a1a2c',
#    'application_number': 'part333A',
#    'brand_name_base': 'Hand Sanitizer'},
#   {'product_ndc': '77272-011',
#    'generic_name': 'Isopropyl Alcohol',
#    'labeler_name': 'ALL BETTER CBD',
#    'brand_name': 'Hand Sanitizer',
#    'active_ingredients': [{'name': 'ISOPROPYL ALCOHOL',
#      'strength': '75 mL/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77272-011-15',
#      'description': '15 mL in 1 BOTTLE (77272-011-15)',
#      'marketing_start_date': '20200330',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['ALL BETTER CBD'],
#     'spl_set_id': ['a853b7a2-1d55-b49b-e053-2a95a90a4fd3'],
#     'is_original_packager': [True],
#     'unii': ['ND2M416302']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'GEL',
#    'spl_id': 'd72981c8-4599-d71e-e053-2a95a90a9647',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200330',
#    'product_id': '77272-011_d72981c8-4599-d71e-e053-2a95a90a9647',
#    'application_number': 'part333A',
#    'brand_name_base': 'Hand Sanitizer'},
#   {'product_ndc': '77272-014',
#    'generic_name': 'Isopropyl Alcohol',
#    'labeler_name': 'ALL BETTER CBD',
#    'brand_name': 'Hand Sanitizer',
#    'active_ingredients': [{'name': 'ISOPROPYL ALCOHOL',
#      'strength': '75 mL/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77272-014-38',
#      'description': '3785 mL in 1 BOTTLE (77272-014-38)',
#      'marketing_start_date': '20200330',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['ALL BETTER CBD'],
#     'spl_set_id': ['a830f7de-7973-7c99-e053-2a95a90aa6cb'],
#     'is_original_packager': [True],
#     'unii': ['ND2M416302']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'GEL',
#    'spl_id': 'd72a510f-9733-15f6-e053-2a95a90a2691',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200330',
#    'product_id': '77272-014_d72a510f-9733-15f6-e053-2a95a90a2691',
#    'application_number': 'part333A',
#    'brand_name_base': 'Hand Sanitizer'},
#   {'product_ndc': '77272-240',
#    'generic_name': 'Isopropyl Alcohol',
#    'labeler_name': 'ALL BETTER CBD',
#    'brand_name': 'Hand Sanitizer',
#    'active_ingredients': [{'name': 'ISOPROPYL ALCOHOL',
#      'strength': '75 mL/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77272-240-10',
#      'description': '100 mL in 1 BOTTLE (77272-240-10)',
#      'marketing_start_date': '20200330',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['ALL BETTER CBD'],
#     'spl_set_id': ['a7a0ea3b-b3a2-705b-e053-2995a90a68b8'],
#     'is_original_packager': [True],
#     'unii': ['ND2M416302']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'GEL',
#    'spl_id': 'd72a6993-c85a-361f-e053-2995a90a38ca',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200330',
#    'product_id': '77272-240_d72a6993-c85a-361f-e053-2995a90a38ca',
#    'application_number': 'part333A',
#    'brand_name_base': 'Hand Sanitizer'},
#   {'product_ndc': '0615-8371',
#    'generic_name': 'Trazodone Hydrochloride',
#    'labeler_name': 'NCS HealthCare of KY, LLC dba Vangard Labs',
#    'brand_name': 'Trazodone Hydrochloride',
#    'active_ingredients': [{'name': 'TRAZODONE HYDROCHLORIDE',
#      'strength': '50 mg/1'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '0615-8371-05',
#      'description': '15 TABLET in 1 BLISTER PACK (0615-8371-05)',
#      'marketing_start_date': '20220211',
#      'sample': False},
#     {'package_ndc': '0615-8371-07',
#      'description': '7 TABLET in 1 BLISTER PACK (0615-8371-07)',
#      'marketing_start_date': '20221208',
#      'sample': False},
#     {'package_ndc': '0615-8371-14',
#      'description': '14 TABLET in 1 BLISTER PACK (0615-8371-14)',
#      'marketing_start_date': '20221208',
#      'sample': False},
#     {'package_ndc': '0615-8371-39',
#      'description': '30 TABLET in 1 BLISTER PACK (0615-8371-39)',
#      'marketing_start_date': '20220211',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['NCS HealthCare of KY, LLC dba Vangard Labs'],
#     'rxcui': ['856364', '856377'],
#     'spl_set_id': ['310c4b81-d2cf-4014-873d-e71d036105de'],
#     'unii': ['6E8ZO8LRNM']},
#    'marketing_category': 'ANDA',
#    'dosage_form': 'TABLET',
#    'spl_id': '131756ec-f2c5-4c77-8524-0fec4d1b268e',
#    'product_type': 'HUMAN PRESCRIPTION DRUG',
#    'route': ['ORAL'],
#    'marketing_start_date': '20201001',
#    'product_id': '0615-8371_131756ec-f2c5-4c77-8524-0fec4d1b268e',
#    'application_number': 'ANDA071523',
#    'brand_name_base': 'Trazodone Hydrochloride',
#    'pharm_class': ['Serotonin Reuptake Inhibitor [EPC]']},
#   {'product_ndc': '77272-420',
#    'generic_name': 'Isopropyl Alcohol',
#    'labeler_name': 'ALL BETTER CBD',
#    'brand_name': 'Hand Sanitizer',
#    'active_ingredients': [{'name': 'ISOPROPYL ALCOHOL',
#      'strength': '75 mL/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77272-420-08',
#      'description': '240 mL in 1 BOTTLE (77272-420-08)',
#      'marketing_start_date': '20200330',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['ALL BETTER CBD'],
#     'rxcui': ['1039900'],
#     'spl_set_id': ['a5f7ed01-5336-87db-e053-2a95a90ade2a'],
#     'is_original_packager': [True],
#     'unii': ['ND2M416302']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'LIQUID',
#    'spl_id': 'd7293671-3b25-e2fd-e053-2995a90ad746',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200330',
#    'product_id': '77272-420_d7293671-3b25-e2fd-e053-2995a90ad746',
#    'application_number': 'part333A',
#    'brand_name_base': 'Hand Sanitizer'},
#   {'product_ndc': '77272-420',
#    'generic_name': 'Isopropyl Alcohol',
#    'labeler_name': 'ALL BETTER CBD',
#    'brand_name': 'Hand Sanitizer',
#    'active_ingredients': [{'name': 'ISOPROPYL ALCOHOL',
#      'strength': '75 mL/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77272-420-16',
#      'description': '17 mL in 1 BOTTLE (77272-420-16)',
#      'marketing_start_date': '20200330',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['ALL BETTER CBD'],
#     'rxcui': ['1039900'],
#     'spl_set_id': ['a643800d-0494-8581-e053-2995a90a0f09'],
#     'is_original_packager': [True],
#     'unii': ['ND2M416302']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'LIQUID',
#    'spl_id': 'd72a6993-c85d-361f-e053-2995a90a38ca',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200330',
#    'product_id': '77272-420_d72a6993-c85d-361f-e053-2995a90a38ca',
#    'application_number': 'part333A',
#    'brand_name_base': 'Hand Sanitizer'},
#   {'product_ndc': '77277-634',
#    'generic_name': 'Ethyl Alcohol',
#    'labeler_name': 'CARONLAB AUSTRALIA PTY LTD',
#    'brand_name': 'Micro Defence Antiseptic Hand Sanitizer',
#    'active_ingredients': [{'name': 'ALCOHOL', 'strength': '80 mL/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77277-634-17',
#      'description': '500 mL in 1 BOTTLE (77277-634-17)',
#      'marketing_start_date': '20200622',
#      'sample': False},
#     {'package_ndc': '77277-634-34',
#      'description': '1000 mL in 1 BOTTLE (77277-634-34)',
#      'marketing_start_date': '20200622',
#      'sample': False},
#     {'package_ndc': '77277-634-42',
#      'description': '125 mL in 1 BOTTLE (77277-634-42)',
#      'marketing_start_date': '20200622',
#      'sample': False},
#     {'package_ndc': '77277-634-85',
#      'description': '250 mL in 1 BOTTLE (77277-634-85)',
#      'marketing_start_date': '20200622',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['CARONLAB AUSTRALIA PTY LTD'],
#     'rxcui': ['1041498'],
#     'spl_set_id': ['213dcb3a-bfa9-4945-b2e0-86215237d620'],
#     'is_original_packager': [True],
#     'upc': ['0877365009425'],
#     'unii': ['3K9958V90M']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'GEL',
#    'spl_id': '1488381a-2503-4e60-a763-5989ea766c75',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200622',
#    'product_id': '77277-634_1488381a-2503-4e60-a763-5989ea766c75',
#    'application_number': 'part333A',
#    'brand_name_base': 'Micro Defence Antiseptic Hand Sanitizer'},
#   {'product_ndc': '77338-014',
#    'generic_name': 'Skin Protectant',
#    'labeler_name': 'ASTONEA LABS PRIVATE LIMITED',
#    'brand_name': 'Tenderphor',
#    'active_ingredients': [{'name': 'PETROLATUM', 'strength': '44.28 g/100g'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77338-014-23',
#      'description': '113 g in 1 TUBE (77338-014-23)',
#      'marketing_start_date': '20220817',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['ASTONEA LABS PRIVATE LIMITED'],
#     'rxcui': ['2609764'],
#     'spl_set_id': ['e676a19c-c214-3307-e053-2a95a90a6e36'],
#     'is_original_packager': [True],
#     'unii': ['4T6H12BN9U']},
#    'marketing_category': 'OTC MONOGRAPH FINAL',
#    'dosage_form': 'OINTMENT',
#    'spl_id': 'e676a19c-c215-3307-e053-2a95a90a6e36',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20220817',
#    'product_id': '77338-014_e676a19c-c215-3307-e053-2a95a90a6e36',
#    'application_number': 'part347',
#    'brand_name_base': 'Tenderphor'},
#   {'product_ndc': '77338-091',
#    'generic_name': 'Sodium Floride',
#    'labeler_name': 'ASTONEA LABS PRIVATE LIMITED',
#    'brand_name': 'ASTONEA -SODIUM FLUORIDE',
#    'active_ingredients': [{'name': 'SODIUM FLUORIDE',
#      'strength': '.22 g/100g'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77338-091-38',
#      'description': '43 g in 1 TUBE (77338-091-38)',
#      'marketing_start_date': '20150115',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['ASTONEA LABS PRIVATE LIMITED'],
#     'rxcui': ['245598'],
#     'spl_set_id': ['e69bc270-e909-1139-e053-2995a90a039b'],
#     'is_original_packager': [True],
#     'unii': ['8ZYQ1474W7']},
#    'marketing_category': 'OTC MONOGRAPH FINAL',
#    'dosage_form': 'PASTE, DENTIFRICE',
#    'spl_id': 'ef052828-db6d-d7a8-e053-2995a90a9031',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['DENTAL'],
#    'marketing_start_date': '20150115',
#    'product_id': '77338-091_ef052828-db6d-d7a8-e053-2995a90a9031',
#    'application_number': 'part355',
#    'brand_name_base': 'ASTONEA -SODIUM FLUORIDE'},
#   {'product_ndc': '0615-8375',
#    'generic_name': 'Aripiprazole',
#    'labeler_name': 'NCS HealthCare of KY, LLC dba Vangard Labs',
#    'brand_name': 'Aripiprazole',
#    'active_ingredients': [{'name': 'ARIPIPRAZOLE', 'strength': '5 mg/1'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '0615-8375-39',
#      'description': '30 TABLET in 1 BLISTER PACK (0615-8375-39)',
#      'marketing_start_date': '20210203',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['NCS HealthCare of KY, LLC dba Vangard Labs'],
#     'rxcui': ['402131'],
#     'spl_set_id': ['8da99c93-613e-4b78-9f91-3efc2dea194d'],
#     'nui': ['N0000175430'],
#     'pharm_class_epc': ['Atypical Antipsychotic [EPC]'],
#     'unii': ['82VFR53I78']},
#    'marketing_category': 'ANDA',
#    'dosage_form': 'TABLET',
#    'spl_id': 'e8de660c-3ea9-489c-aca4-8b7c6e3f428f',
#    'product_type': 'HUMAN PRESCRIPTION DRUG',
#    'route': ['ORAL'],
#    'marketing_start_date': '20200316',
#    'product_id': '0615-8375_e8de660c-3ea9-489c-aca4-8b7c6e3f428f',
#    'application_number': 'ANDA206383',
#    'brand_name_base': 'Aripiprazole',
#    'pharm_class': ['Atypical Antipsychotic [EPC]']},
#   {'product_ndc': '77338-304',
#    'generic_name': 'Zinc Oxide',
#    'labeler_name': 'ASTONEA LABS PRIVATE LIMITED',
#    'brand_name': 'ASTONEA',
#    'active_ingredients': [{'name': 'ZINC OXIDE', 'strength': '20 g/100g'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77338-304-03',
#      'description': '28.3 g in 1 TUBE (77338-304-03)',
#      'marketing_start_date': '20130523',
#      'sample': False},
#     {'package_ndc': '77338-304-04',
#      'description': '56.6 g in 1 TUBE (77338-304-04)',
#      'marketing_start_date': '20130523',
#      'sample': False},
#     {'package_ndc': '77338-304-05',
#      'description': '425 g in 1 JAR (77338-304-05)',
#      'marketing_start_date': '20130523',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['ASTONEA LABS PRIVATE LIMITED'],
#     'rxcui': ['198911'],
#     'spl_set_id': ['e68b34ea-0cb3-574f-e053-2995a90ad828'],
#     'is_original_packager': [True],
#     'unii': ['SOI2LOH54Z']},
#    'marketing_category': 'OTC MONOGRAPH FINAL',
#    'dosage_form': 'OINTMENT',
#    'spl_id': 'e68b3524-ed6f-55ec-e053-2995a90ab29c',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20130523',
#    'product_id': '77338-304_e68b3524-ed6f-55ec-e053-2995a90ab29c',
#    'application_number': 'part347',
#    'brand_name_base': 'ASTONEA'},
#   {'product_ndc': '77368-018',
#    'generic_name': 'ALCOHOL',
#    'labeler_name': 'NuGenTec',
#    'brand_name': 'NuRinse Hand Sanitizing Wipe',
#    'active_ingredients': [{'name': 'ALCOHOL', 'strength': '80 mL/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77368-018-10',
#      'description': '2.7 mL in 1 CANISTER (77368-018-10)',
#      'marketing_start_date': '20200930',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['NuGenTec'],
#     'rxcui': ['2361646'],
#     'spl_set_id': ['af40b98e-74e3-8713-e053-2995a90a1e42'],
#     'is_original_packager': [True],
#     'upc': ['0051497169022'],
#     'unii': ['3K9958V90M']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'CLOTH',
#    'spl_id': 'f0741174-25cd-07a0-e053-2995a90a5fa3',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200330',
#    'product_id': '77368-018_f0741174-25cd-07a0-e053-2995a90a5fa3',
#    'application_number': 'part333A',
#    'brand_name_base': 'NuRinse Hand Sanitizing Wipe'},
#   {'product_ndc': '77368-074',
#    'generic_name': 'ETHYL ALCOHOL',
#    'labeler_name': 'NuGenTec',
#    'brand_name': 'NuRinse 1 Gal',
#    'brand_name_suffix': '1 Gal',
#    'active_ingredients': [{'name': 'ALCOHOL', 'strength': '70 mL/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77368-074-01',
#      'description': '3785 mL in 1 BOTTLE (77368-074-01)',
#      'marketing_start_date': '20200901',
#      'sample': False},
#     {'package_ndc': '77368-074-08',
#      'description': '237 mL in 1 BOTTLE (77368-074-08)',
#      'marketing_start_date': '20200901',
#      'sample': False},
#     {'package_ndc': '77368-074-12',
#      'description': '355 mL in 1 BOTTLE (77368-074-12)',
#      'marketing_start_date': '20200901',
#      'sample': False},
#     {'package_ndc': '77368-074-16',
#      'description': '473 mL in 1 BOTTLE (77368-074-16)',
#      'marketing_start_date': '20200901',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['NuGenTec'],
#     'rxcui': ['581662'],
#     'spl_set_id': ['b74e07b2-961c-5761-e053-2995a90a60e6'],
#     'is_original_packager': [True],
#     'unii': ['3K9958V90M']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'GEL',
#    'spl_id': 'f0743f09-61e1-4b57-e053-2a95a90ad69a',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200828',
#    'product_id': '77368-074_f0743f09-61e1-4b57-e053-2a95a90ad69a',
#    'application_number': 'part333A',
#    'brand_name_base': 'NuRinse'},
#   {'product_ndc': '77368-080',
#    'generic_name': 'Hand Sanitizer WHO1',
#    'labeler_name': 'NuGenTec',
#    'brand_name': 'NuRinse',
#    'active_ingredients': [{'name': 'ALCOHOL', 'strength': '80 mL/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77368-080-01',
#      'description': '3785 mL in 1 BOTTLE (77368-080-01)',
#      'marketing_start_date': '20200505',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['NuGenTec'],
#     'rxcui': ['1039339'],
#     'spl_set_id': ['a4dff3bb-c8b8-a28e-e053-2a95a90af569'],
#     'is_original_packager': [True],
#     'unii': ['3K9958V90M']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'LIQUID',
#    'spl_id': 'f0740a70-03d3-a537-e053-2a95a90a17af',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200505',
#    'product_id': '77368-080_f0740a70-03d3-a537-e053-2a95a90a17af',
#    'application_number': 'part333A',
#    'brand_name_base': 'NuRinse'},
#   {'product_ndc': '77368-388',
#    'generic_name': 'Hand Sanitizer HOCL Aloe and Vitamin E Gel',
#    'labeler_name': 'NuGenTec',
#    'brand_name': 'NuRinse',
#    'active_ingredients': [{'name': 'HYPOCHLOROUS ACID',
#      'strength': '.000385 g/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77368-388-05',
#      'description': '18927 mL in 1 BOTTLE (77368-388-05)',
#      'marketing_start_date': '20200505',
#      'sample': False},
#     {'package_ndc': '77368-388-08',
#      'description': '237 mL in 1 BOTTLE (77368-388-08)',
#      'marketing_start_date': '20200505',
#      'sample': False},
#     {'package_ndc': '77368-388-12',
#      'description': '355 mL in 1 BOTTLE (77368-388-12)',
#      'marketing_start_date': '20200505',
#      'sample': False},
#     {'package_ndc': '77368-388-16',
#      'description': '474 mL in 1 BOTTLE (77368-388-16)',
#      'marketing_start_date': '20200505',
#      'sample': False},
#     {'package_ndc': '77368-388-55',
#      'description': '208198 mL in 1 BOTTLE (77368-388-55)',
#      'marketing_start_date': '20200505',
#      'sample': False},
#     {'package_ndc': '77368-388-75',
#      'description': '10409875 mL in 1 BOTTLE (77368-388-75)',
#      'marketing_start_date': '20200505',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['NuGenTec'],
#     'spl_set_id': ['d9bfd81f-7fd1-24df-e053-2995a90af0da'],
#     'is_original_packager': [True],
#     'unii': ['712K4CDC10']},
#    'marketing_category': 'UNAPPROVED DRUG OTHER',
#    'dosage_form': 'GEL',
#    'spl_id': 'f0741faf-3e43-9966-e053-2995a90a0178',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200505',
#    'product_id': '77368-388_f0741faf-3e43-9966-e053-2995a90a0178',
#    'brand_name_base': 'NuRinse'},
#   {'product_ndc': '77371-126',
#    'generic_name': 'Isopropyl Alcohol',
#    'labeler_name': 'NICETY SOLUTIONS LLC',
#    'brand_name': 'Adventure Hand Sanitizer - Fragrance 60%',
#    'active_ingredients': [{'name': 'ISOPROPYL ALCOHOL',
#      'strength': '.6 mL/mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77371-126-01',
#      'description': '38 mL in 1 BOTTLE, SPRAY (77371-126-01)',
#      'marketing_start_date': '20200505',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['NICETY SOLUTIONS LLC'],
#     'rxcui': ['2362254'],
#     'spl_set_id': ['a5080b86-c61d-5043-e053-2a95a90a6f33'],
#     'is_original_packager': [True],
#     'unii': ['ND2M416302']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'SPRAY',
#    'spl_id': 'e43ea518-6b85-677e-e053-2995a90ab323',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200505',
#    'product_id': '77371-126_e43ea518-6b85-677e-e053-2995a90ab323',
#    'application_number': 'part333E',
#    'brand_name_base': 'Adventure Hand Sanitizer - Fragrance 60%'},
#   {'product_ndc': '77386-903',
#    'generic_name': 'ALCOHOL',
#    'labeler_name': 'Community Chemical',
#    'brand_name': 'Hand Sanitizer',
#    'active_ingredients': [{'name': 'ALCOHOL', 'strength': '80 mL/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77386-903-01',
#      'description': '59 mL in 1 BOTTLE (77386-903-01)',
#      'marketing_start_date': '20200330',
#      'sample': False},
#     {'package_ndc': '77386-903-02',
#      'description': '118 mL in 1 BOTTLE (77386-903-02)',
#      'marketing_start_date': '20200330',
#      'sample': False},
#     {'package_ndc': '77386-903-03',
#      'description': '236 mL in 1 BOTTLE (77386-903-03)',
#      'marketing_start_date': '20200330',
#      'sample': False},
#     {'package_ndc': '77386-903-04',
#      'description': '946 mL in 1 BOTTLE (77386-903-04)',
#      'marketing_start_date': '20200330',
#      'sample': False},
#     {'package_ndc': '77386-903-05',
#      'description': '3785 mL in 1 BOTTLE (77386-903-05)',
#      'marketing_start_date': '20200330',
#      'sample': False},
#     {'package_ndc': '77386-903-06',
#      'description': '208198 mL in 1 DRUM (77386-903-06)',
#      'marketing_start_date': '20200330',
#      'sample': False},
#     {'package_ndc': '77386-903-11',
#      'description': '59 mL in 1 BOTTLE (77386-903-11)',
#      'marketing_start_date': '20200330',
#      'sample': False},
#     {'package_ndc': '77386-903-12',
#      'description': '118 mL in 1 BOTTLE (77386-903-12)',
#      'marketing_start_date': '20200330',
#      'sample': False},
#     {'package_ndc': '77386-903-13',
#      'description': '236 mL in 1 BOTTLE (77386-903-13)',
#      'marketing_start_date': '20200330',
#      'sample': False},
#     {'package_ndc': '77386-903-14',
#      'description': '946 mL in 1 BOTTLE (77386-903-14)',
#      'marketing_start_date': '20200330',
#      'sample': False},
#     {'package_ndc': '77386-903-15',
#      'description': '3785 mL in 1 BOTTLE (77386-903-15)',
#      'marketing_start_date': '20200330',
#      'sample': False},
#     {'package_ndc': '77386-903-16',
#      'description': '208198 mL in 1 DRUM (77386-903-16)',
#      'marketing_start_date': '20200330',
#      'sample': False},
#     {'package_ndc': '77386-903-17',
#      'description': '1248185 mL in 1 CONTAINER (77386-903-17)',
#      'marketing_start_date': '20200330',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['Community Chemical'],
#     'rxcui': ['1039339'],
#     'spl_set_id': ['a3d3286a-6279-9f12-e053-2995a90a2be0'],
#     'is_original_packager': [True],
#     'upc': ['0860003871607'],
#     'unii': ['3K9958V90M']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'LIQUID',
#    'spl_id': 'd5cc96b5-2fd4-fe2b-e053-2995a90af06a',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200330',
#    'product_id': '77386-903_d5cc96b5-2fd4-fe2b-e053-2995a90af06a',
#    'application_number': 'part333A',
#    'brand_name_base': 'Hand Sanitizer'},
#   {'product_ndc': '77411-001',
#    'generic_name': 'Hand Sanitizer',
#    'labeler_name': 'SMC Technologies',
#    'brand_name': 'Clean N Fresh',
#    'active_ingredients': [{'name': 'ALCOHOL', 'strength': '70 mL/100mL'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77411-001-01',
#      'description': '3785 mL in 1 JUG (77411-001-01)',
#      'marketing_start_date': '20200330',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['SMC Technologies'],
#     'rxcui': ['581662'],
#     'spl_set_id': ['a5107d3c-18d9-9d6b-e053-2995a90a6940'],
#     'is_original_packager': [True],
#     'unii': ['3K9958V90M']},
#    'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#    'dosage_form': 'GEL',
#    'spl_id': 'f0e6b514-51b1-1111-e053-2995a90adb1b',
#    'product_type': 'HUMAN OTC DRUG',
#    'route': ['TOPICAL'],
#    'marketing_start_date': '20200330',
#    'product_id': '77411-001_f0e6b514-51b1-1111-e053-2995a90adb1b',
#    'application_number': 'part333A',
#    'brand_name_base': 'Clean N Fresh'},
#   {'product_ndc': '77411-003',
#    'generic_name': 'Hand Sanitizer',
#    'labeler_name': 'SMC Technologies',
#    'brand_name': 'Clean N Fresh 02',
#    'active_ingredients': [{'name': 'ALCOHOL', 'strength': '146 L/209.198L'}],
#    'finished': True,
#    'packaging': [{'package_ndc': '77411-003-55',
#      'description': '209.198 L in 1 DRUM (77411-003-55)',
#      'marketing_start_date': '20200330',
#      'sample': False}],
#    'listing_expiration_date': '20231231',
#    'openfda': {'manufacturer_name': ['SMC Technologies'],
#     'spl_set_id': ['a967e58e-25d4-f028-e053-2a95a90a8f1b'],
#     'is_original_packager': [True],
# ...
#    'openfda': {},
#    'marketing_category': 'BULK INGREDIENT',
#    'dosage_form': 'POWDER',
#    'spl_id': 'f188643f-c24d-34d9-e053-2a95a90ac433',
#    'product_type': 'BULK INGREDIENT',
#    'marketing_start_date': '20190225',
#    'product_id': '29902-0023_f188643f-c24d-34d9-e053-2a95a90ac433',
#    'brand_name_base': None},
#   {'product_ndc': '29902-0024',
#    'generic_name': 'Maropitant Citrate',
#    'labeler_name': 'Sichuan Credit Chemwerth Pharmaceutical Co. Ltd.',
#    'active_ingredients': [{'name': 'MAROPITANT CITRATE',
#      'strength': '1 kg/kg'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '29902-0024-1',
#      'description': '1 kg in 1 BAG (29902-0024-1)',
#      'marketing_start_date': '30-JUL-19'}],
#    'listing_expiration_date': '20241231',
#    'openfda': {},
#    'marketing_category': 'BULK INGREDIENT',
#    'dosage_form': 'POWDER',
#    'spl_id': 'f188643f-c24e-34d9-e053-2a95a90ac433',
#    'product_type': 'BULK INGREDIENT',
#    'marketing_start_date': '20190730',
#    'product_id': '29902-0024_f188643f-c24e-34d9-e053-2a95a90ac433',
#    'brand_name_base': None},
#   {'product_ndc': '29967-0007',
#    'generic_name': 'Dapsone',
#    'labeler_name': 'Aragen Life Sciences Private Limited',
#    'active_ingredients': [{'name': 'DAPSONE', 'strength': '1 kg/kg'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '29967-0007-0',
#      'description': '25 kg in 1 DRUM (29967-0007-0)',
#      'marketing_start_date': '11-FEB-20'}],
#    'listing_expiration_date': '20231231',
#    'openfda': {},
#    'marketing_category': 'BULK INGREDIENT',
#    'dosage_form': 'POWDER',
#    'spl_id': 'b85452a3-be57-4a5c-e053-2a95a90abf8f',
#    'product_type': 'BULK INGREDIENT',
#    'marketing_start_date': '20200211',
#    'product_id': '29967-0007_b85452a3-be57-4a5c-e053-2a95a90abf8f',
#    'brand_name_base': None},
#   {'product_ndc': '30007-830',
#    'generic_name': 'Norethindrone Fine Grade',
#    'labeler_name': "Dr.Reddy's Laboratories Limited",
#    'active_ingredients': [{'name': 'NORETHINDRONE', 'strength': '1 kg/kg'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '30007-830-00',
#      'description': '1 kg in 1 DRUM (30007-830-00)',
#      'marketing_start_date': '01-JAN-10'}],
#    'listing_expiration_date': '20231231',
#    'openfda': {},
#    'marketing_category': 'BULK INGREDIENT',
#    'dosage_form': 'POWDER',
#    'spl_id': '2b1d6d4e-6442-8251-d9c7-9eff80e7b8c4',
#    'product_type': 'BULK INGREDIENT',
#    'marketing_start_date': '20100101',
#    'product_id': '30007-830_2b1d6d4e-6442-8251-d9c7-9eff80e7b8c4',
#    'brand_name_base': None},
#   {'product_ndc': '30032-151',
#    'generic_name': 'Povidone-Iodine',
#    'labeler_name': 'Thatcher Company',
#    'active_ingredients': [{'name': 'POVIDONE-IODINE', 'strength': '1 kg/kg'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '30032-151-10',
#      'description': '50 kg in 1 DRUM (30032-151-10)',
#      'marketing_start_date': '29-MAR-13'}],
#    'listing_expiration_date': '20231231',
#    'openfda': {},
#    'marketing_category': 'DRUG FOR FURTHER PROCESSING',
#    'dosage_form': 'POWDER',
#    'spl_id': 'ebd482fb-dd8c-6296-e053-2a95a90ad5e1',
#    'product_type': 'DRUG FOR FURTHER PROCESSING',
#    'marketing_start_date': '20130329',
#    'product_id': '30032-151_ebd482fb-dd8c-6296-e053-2a95a90ad5e1',
#    'brand_name_base': None},
#   {'product_ndc': '31260-218',
#    'generic_name': 'ALUMINUM ZIRCONIUM TETRACHLOROHYDREX GLYCINE',
#    'labeler_name': 'Gulbrandsen Technologies India Private Limited',
#    'active_ingredients': [{'name': 'ALUMINUM ZIRCONIUM TETRACHLOROHYDREX GLY',
#      'strength': '1 kg/kg'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '31260-218-01',
#      'description': '136 kg in 1 DRUM (31260-218-01)',
#      'marketing_start_date': '23-JUL-09'},
#     {'package_ndc': '31260-218-02',
#      'description': '635 kg in 1 SUPERSACK (31260-218-02)',
#      'marketing_start_date': '23-JUL-09'}],
#    'listing_expiration_date': '20231231',
#    'openfda': {},
#    'marketing_category': 'BULK INGREDIENT',
#    'dosage_form': 'POWDER',
#    'spl_id': 'f0297c8f-612a-5d08-e053-2995a90ad750',
#    'product_type': 'BULK INGREDIENT',
#    'marketing_start_date': '20090723',
#    'product_id': '31260-218_f0297c8f-612a-5d08-e053-2995a90ad750',
#    'brand_name_base': None},
#   {'product_ndc': '31387-205',
#    'generic_name': 'Pancrelipase',
#    'labeler_name': 'Scientific Protein Laboratories LLC',
#    'active_ingredients': [{'name': 'PANCRELIPASE', 'strength': '1 kg/kg'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '31387-205-03',
#      'description': '50 kg in 1 DRUM (31387-205-03)',
#      'marketing_start_date': '02-FEB-04'}],
#    'listing_expiration_date': '20231231',
#    'openfda': {},
#    'marketing_category': 'BULK INGREDIENT',
#    'dosage_form': 'POWDER',
#    'spl_id': 'ec927c88-05b2-b1d9-e053-2a95a90a7dce',
#    'product_type': 'BULK INGREDIENT',
#    'marketing_start_date': '20040202',
#    'product_id': '31387-205_ec927c88-05b2-b1d9-e053-2a95a90a7dce',
#    'brand_name_base': None},
#   {'product_ndc': '32861-0001',
#    'generic_name': 'bivalirudin',
#    'labeler_name': 'Chengdu Shengnuo Biopharm Co. Ltd',
#    'active_ingredients': [{'name': 'BIVALIRUDIN', 'strength': '1 kg/kg'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '32861-0001-1',
#      'description': '10 kg in 1 BOTTLE, GLASS (32861-0001-1)',
#      'marketing_start_date': '13-DEC-17'}],
#    'listing_expiration_date': '20241231',
#    'openfda': {},
#    'marketing_category': 'BULK INGREDIENT',
#    'dosage_form': 'POWDER',
#    'spl_id': 'f1886f86-7ef8-ca35-e053-2a95a90ac830',
#    'product_type': 'BULK INGREDIENT',
#    'marketing_start_date': '20111207',
#    'product_id': '32861-0001_f1886f86-7ef8-ca35-e053-2a95a90ac830',
#    'brand_name_base': None},
#   {'product_ndc': '32995-5421',
#    'generic_name': 'metformin hydrochloride',
#    'labeler_name': 'Vistin Pharma AS',
#    'active_ingredients': [{'name': 'METFORMIN HYDROCHLORIDE',
#      'strength': '1 kg/kg'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '32995-5421-1',
#      'description': '1 BAG in 1 CARTON (32995-5421-1)  / 25 kg in 1 BAG',
#      'marketing_start_date': '17-FEB-06'}],
#    'listing_expiration_date': '20231231',
#    'openfda': {},
#    'marketing_category': 'BULK INGREDIENT',
#    'dosage_form': 'POWDER',
#    'spl_id': 'd32eb5e1-bbc3-60a6-e053-2a95a90a6087',
#    'product_type': 'BULK INGREDIENT',
#    'marketing_start_date': '20060217',
#    'product_id': '32995-5421_d32eb5e1-bbc3-60a6-e053-2a95a90a6087',
#    'brand_name_base': None},
#   {'product_ndc': '33342-504',
#    'generic_name': 'Vardenafil Hydrochloride Trihydrate',
#    'labeler_name': 'Macleods Pharmaceuticals Limited',
#    'active_ingredients': [{'name': 'VARDENAFIL HYDROCHLORIDE TRIHYDRATE',
#      'strength': '25 kg/25kg'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '33342-504-82',
#      'description': '25 kg in 1 CONTAINER (33342-504-82)',
#      'marketing_start_date': '24-FEB-16'}],
#    'listing_expiration_date': '20231231',
#    'openfda': {},
#    'marketing_category': 'BULK INGREDIENT',
#    'dosage_form': 'POWDER',
#    'spl_id': 'eb37fbc9-0e38-09fb-e053-2a95a90a41de',
#    'product_type': 'BULK INGREDIENT',
#    'marketing_start_date': '20160224',
#    'product_id': '33342-504_eb37fbc9-0e38-09fb-e053-2a95a90a41de',
#    'brand_name_base': None},
#   {'product_ndc': '33656-0017',
#    'generic_name': 'Epinastine Hydrochloride',
#    'labeler_name': 'Chongqing Biocare Pharmaceutical Ltd.',
#    'active_ingredients': [{'name': 'NELARABINE', 'strength': '1 g/g'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '33656-0017-1',
#      'description': '1 g in 1 POUCH (33656-0017-1)',
#      'marketing_start_date': '22-SEP-20'}],
#    'listing_expiration_date': '20231231',
#    'openfda': {},
#    'marketing_category': 'BULK INGREDIENT',
#    'dosage_form': 'POWDER',
#    'spl_id': 'de217e1f-6968-8bf3-e053-2995a90acf8a',
#    'product_type': 'BULK INGREDIENT',
#    'marketing_start_date': '20200922',
#    'product_id': '33656-0017_de217e1f-6968-8bf3-e053-2995a90acf8a',
#    'brand_name_base': None},
#   {'product_ndc': '35369-0006',
#    'generic_name': 'Hydroxyurea',
#    'labeler_name': 'Shandong Anxin Pharmaceutical Co., Ltd.',
#    'active_ingredients': [{'name': 'HYDROXYUREA', 'strength': '25 kg/25kg'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '35369-0006-1',
#      'description': '25 kg in 1 DRUM (35369-0006-1)',
#      'marketing_start_date': '11-APR-19'}],
#    'listing_expiration_date': '20231231',
#    'openfda': {},
#    'marketing_category': 'BULK INGREDIENT FOR HUMAN PRESCRIPTION COMPOUNDING',
#    'dosage_form': 'POWDER',
#    'spl_id': '655ab5a8-d02f-4565-acb3-dd8bd482ac87',
#    'product_type': 'BULK INGREDIENT',
#    'marketing_start_date': '20190411',
#    'product_id': '35369-0006_655ab5a8-d02f-4565-acb3-dd8bd482ac87',
#    'brand_name_base': None},
#   {'product_ndc': '35369-0007',
#    'generic_name': 'Piperacillin Sodium and Tazobactam Sodium',
#    'labeler_name': 'Shandong Anxin Pharmaceutical Co., Ltd.',
#    'active_ingredients': [{'name': 'PIPERACILLIN SODIUM',
#      'strength': '8.86 kg/10kg'},
#     {'name': 'TAZOBACTAM SODIUM', 'strength': '1.14 kg/10kg'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '35369-0007-2',
#      'description': '1 CANISTER in 1 CARTON (35369-0007-2)  / 10 kg in 1 CANISTER (35369-0007-1)',
#      'marketing_start_date': '23-NOV-19'}],
#    'listing_expiration_date': '20231231',
#    'openfda': {},
#    'marketing_category': 'BULK INGREDIENT FOR HUMAN PRESCRIPTION COMPOUNDING',
#    'dosage_form': 'POWDER',
#    'spl_id': '1132e62f-56e2-4cd2-a69b-a4a882d76559',
#    'product_type': 'BULK INGREDIENT',
#    'marketing_start_date': '20191123',
#    'product_id': '35369-0007_1132e62f-56e2-4cd2-a69b-a4a882d76559',
#    'brand_name_base': None},
#   {'product_ndc': '36974-0043',
#    'generic_name': 'Doxepin HCl',
#    'labeler_name': 'Plantex Ltd',
#    'active_ingredients': [{'name': 'DOXEPIN HYDROCHLORIDE',
#      'strength': '100 kg/100kg'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '36974-0043-0',
#      'description': '1 kg in 1 CARTON (36974-0043-0)',
#      'marketing_start_date': '05-DEC-17'}],
#    'listing_expiration_date': '20231231',
#    'openfda': {},
#    'marketing_category': 'BULK INGREDIENT',
#    'dosage_form': 'POWDER',
#    'spl_id': '3004fcbd-21da-455c-99db-6d3f1e02b9d6',
#    'product_type': 'BULK INGREDIENT',
#    'marketing_start_date': '20171205',
#    'product_id': '36974-0043_3004fcbd-21da-455c-99db-6d3f1e02b9d6',
#    'brand_name_base': None},
#   {'product_ndc': '36974-0066',
#    'generic_name': 'Bivalirudin',
#    'labeler_name': 'Plantex Ltd',
#    'active_ingredients': [{'name': 'BIVALIRUDIN', 'strength': '100 kg/100kg'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '36974-0066-0',
#      'description': '1 kg in 1 CARTON (36974-0066-0)',
#      'marketing_start_date': '22-JUN-17'}],
#    'listing_expiration_date': '20231231',
#    'openfda': {},
#    'marketing_category': 'BULK INGREDIENT',
#    'dosage_form': 'POWDER',
#    'spl_id': '85c4f99a-1a00-4c5d-a61d-2c394264c045',
#    'product_type': 'BULK INGREDIENT',
#    'marketing_start_date': '20170622',
#    'product_id': '36974-0066_85c4f99a-1a00-4c5d-a61d-2c394264c045',
#    'brand_name_base': None},
#   {'product_ndc': '36998-5960',
#    'generic_name': 'levetiracetam',
#    'labeler_name': 'UCB Pharma S.A.',
#    'active_ingredients': [{'name': 'LEVETIRACETAM', 'strength': '750 mg/1'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '36998-5960-0',
#      'description': '22892 TABLET, FILM COATED in 1 DRUM (36998-5960-0)',
#      'marketing_start_date': '24-APR-00'}],
#    'listing_expiration_date': '20231231',
#    'openfda': {},
#    'marketing_category': 'DRUG FOR FURTHER PROCESSING',
#    'dosage_form': 'TABLET, FILM COATED',
#    'spl_id': 'bed95b19-8f36-47bb-a5bb-d679574ebf5e',
#    'product_type': 'DRUG FOR FURTHER PROCESSING',
#    'marketing_start_date': '20000424',
#    'product_id': '36998-5960_bed95b19-8f36-47bb-a5bb-d679574ebf5e',
#    'brand_name_base': None},
#   {'product_ndc': '36998-9550',
#    'generic_name': 'cetirizine hydrochloride and pseudoephedrine hydrochloride',
#    'labeler_name': 'UCB Pharma S.A.',
#    'active_ingredients': [{'name': 'CETIRIZINE HYDROCHLORIDE',
#      'strength': '5 mg/1'},
#     {'name': 'PSEUDOEPHEDRINE HYDROCHLORIDE', 'strength': '120 mg/1'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '36998-9550-0',
#      'description': '251000 TABLET, EXTENDED RELEASE in 1 DRUM (36998-9550-0)',
#      'marketing_start_date': '10-AUG-01'}],
#    'listing_expiration_date': '20231231',
#    'openfda': {},
#    'marketing_category': 'DRUG FOR FURTHER PROCESSING',
#    'dosage_form': 'TABLET, EXTENDED RELEASE',
#    'spl_id': '96e586e6-afd3-44c9-95fa-8bdd1ff8e26c',
#    'product_type': 'DRUG FOR FURTHER PROCESSING',
#    'marketing_start_date': '20010810',
#    'product_id': '36998-9550_96e586e6-afd3-44c9-95fa-8bdd1ff8e26c',
#    'brand_name_base': None},
#   {'product_ndc': '37945-862',
#    'generic_name': 'meradimate, octinoxate, octisalate, oxybenzone',
#    'labeler_name': 'Bio-Medical & Pharmaceutical Manufacturing Corporation',
#    'active_ingredients': [{'name': 'MERADIMATE', 'strength': '50 mg/g'},
#     {'name': 'OCTINOXATE', 'strength': '75 mg/g'},
#     {'name': 'OCTISALATE', 'strength': '50 mg/g'},
#     {'name': 'OXYBENZONE', 'strength': '30 mg/g'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '37945-862-10',
#      'description': '185973 g in 1 DRUM (37945-862-10)',
#      'marketing_start_date': '26-MAY-22'}],
#    'listing_expiration_date': '20231231',
#    'openfda': {},
#    'marketing_category': 'DRUG FOR FURTHER PROCESSING',
#    'dosage_form': 'LOTION',
#    'spl_id': 'df3afcc3-22a4-22f2-e053-2995a90a3ea0',
#    'product_type': 'DRUG FOR FURTHER PROCESSING',
#    'marketing_start_date': '20220526',
#    'product_id': '37945-862_df3afcc3-22a4-22f2-e053-2995a90a3ea0',
#    'brand_name_base': None},
#   {'product_ndc': '37946-5593',
#    'generic_name': 'SALICYLIC ACID',
#    'labeler_name': 'Alchemix Corporation',
#    'active_ingredients': [{'name': 'SALICYLIC ACID',
#      'strength': '17.6 kg/100kg'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '37946-5593-1',
#      'description': '163 kg in 1 DRUM (37946-5593-1)',
#      'marketing_start_date': '01-SEP-07'}],
#    'listing_expiration_date': '20231231',
#    'openfda': {},
#    'marketing_category': 'DRUG FOR FURTHER PROCESSING',
#    'dosage_form': 'LIQUID',
#    'spl_id': '69214132-9793-4f08-a7c5-c4c855975b3e',
#    'product_type': 'DRUG FOR FURTHER PROCESSING',
#    'marketing_start_date': '20070901',
#    'product_id': '37946-5593_69214132-9793-4f08-a7c5-c4c855975b3e',
#    'brand_name_base': None},
#   {'product_ndc': '37946-6449',
#    'generic_name': 'HYDROCORTISONE',
#    'labeler_name': 'Alchemix Corporation',
#    'active_ingredients': [{'name': 'HYDROCORTISONE',
#      'strength': '.5 kg/100kg'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '37946-6449-1',
#      'description': '163 kg in 1 DRUM (37946-6449-1)',
#      'marketing_start_date': '01-JAN-07'}],
#    'listing_expiration_date': '20231231',
#    'openfda': {},
#    'marketing_category': 'DRUG FOR FURTHER PROCESSING',
#    'dosage_form': 'LIQUID',
#    'spl_id': '2d622f2e-0525-4b26-a4cd-9ba193290c5f',
#    'product_type': 'DRUG FOR FURTHER PROCESSING',
#    'marketing_start_date': '20070101',
#    'product_id': '37946-6449_2d622f2e-0525-4b26-a4cd-9ba193290c5f',
#    'brand_name_base': None},
#   {'product_ndc': '37946-6646',
#    'generic_name': 'SALICYLIC ACID',
#    'labeler_name': 'Alchemix Corporation',
#    'active_ingredients': [{'name': 'SALICYLIC ACID',
#      'strength': '17 kg/100kg'}],
#    'finished': False,
#    'packaging': [{'package_ndc': '37946-6646-1',
#      'description': '181 kg in 1 DRUM (37946-6646-1)',
#      'marketing_start_date': '14-JUL-12'}],
#    'listing_expiration_date': '20231231',
#    'openfda': {},
#    'marketing_category': 'DRUG FOR FURTHER PROCESSING',
#    'dosage_form': 'GEL',
#    'spl_id': '8050d358-b2d7-41a1-bd35-7b579c80e81d',
#    'product_type': 'DRUG FOR FURTHER PROCESSING',
#    'marketing_start_date': '20120714',
#    'product_id': '37946-6646_8050d358-b2d7-41a1-bd35-7b579c80e81d',
#    'brand_name_base': None},
#   ...]}

# %%
# Delete Meta
del data['meta']

# %%
# Only Keep Results
data=data['results']

# %%
# Print First Object
data[0]
# Out:
# {'product_ndc': '77006-013',
#  'generic_name': 'ALCOHOL',
#  'labeler_name': 'WeCool Toys, Inc.',
#  'brand_name': 'Crazy Clean Hand Sanitizer - Berry Swirl',
#  'active_ingredients': [{'name': 'ALCOHOL', 'strength': '58.36 g/100mL'}],
#  'finished': True,
#  'packaging': [{'package_ndc': '77006-013-01',
#    'description': '30 mL in 1 BOTTLE (77006-013-01)',
#    'marketing_start_date': '20200330',
#    'sample': False},
#   {'package_ndc': '77006-013-02',
#    'description': '249 mL in 1 BOTTLE, PUMP (77006-013-02)',
#    'marketing_start_date': '20200330',
#    'sample': False},
#   {'package_ndc': '77006-013-03',
#    'description': '60 mL in 1 BOTTLE (77006-013-03)',
#    'marketing_start_date': '20200330',
#    'sample': False},
#   {'package_ndc': '77006-013-04',
#    'description': '975 mL in 1 BOTTLE, PUMP (77006-013-04)',
#    'marketing_start_date': '20200723',
#    'sample': False}],
#  'listing_expiration_date': '20231231',
#  'openfda': {'manufacturer_name': ['WeCool Toys, Inc.'],
#   'spl_set_id': ['a6a6b2ae-6fb8-7793-e053-2995a90a2a69'],
#   'is_original_packager': [True],
#   'unii': ['3K9958V90M']},
#  'marketing_category': 'OTC MONOGRAPH NOT FINAL',
#  'dosage_form': 'LIQUID',
#  'spl_id': 'd5660475-f5c5-c05b-e053-2995a90a6fd4',
#  'product_type': 'HUMAN OTC DRUG',
#  'route': ['TOPICAL'],
#  'marketing_start_date': '20200330',
#  'product_id': '77006-013_d5660475-f5c5-c05b-e053-2995a90a6fd4',
#  'application_number': 'part333A',
#  'brand_name_base': 'Crazy Clean Hand Sanitizer - Berry Swirl'}

# %%
# Length of Data
len(data)
# Out:
# 124248

# %% [markdown]
# ##  JSON to Product Data Frame

# %%
# Create a Dartaframe
df = pd.DataFrame(columns=['product_ndc', 'generic_name', 'labeler_name', 'brand_name', 'finished', 'listing_expiration_date', 'marketing_category', 'dosage_form', 'product_type', 'marketing_start_date', 'product_id', 'brand_name_base', 'package_ndc', 'description', 'marketing_start_date', 'marketing_end_date', 'sample'])

# %%
# Iterate over each packaging object and append its fields to the DataFrame
rows = []
for product in data:
    product_ndc = product.get('product_ndc', None)
    generic_name = product.get('generic_name', None)
    labeler_name = product.get('labeler_name', None)
    brand_name = product.get('brand_name', None)
    finished = product.get('finished', None)
    listing_expiration_date = product.get('listing_expiration_date', None)
    marketing_category = product.get('marketing_category', None)
    dosage_form = product.get('dosage_form', None)
    product_type = product.get('product_type', None)
    marketing_start_date = product.get('marketing_start_date', None)
    product_id = product.get('product_id', None)
    brand_name_base = product.get('brand_name_base', None)
    for package in product['packaging']:
        package_ndc = package.get('package_ndc', None)
        description = package.get('description', None)
        marketing_start_date = package.get('marketing_start_date', None)
        marketing_end_date = package.get('marketing_end_date', None)
        sample = package.get('sample', None)
        if package_ndc is not None and description is not None:
            row = {'product_ndc': product_ndc, 'generic_name': generic_name, 'labeler_name': labeler_name, 'brand_name': brand_name, 'finished': finished, 'listing_expiration_date': listing_expiration_date, 'marketing_category': marketing_category, 'dosage_form': dosage_form, 'product_type': product_type, 'marketing_start_date': marketing_start_date, 'product_id': product_id, 'brand_name_base': brand_name_base,'package_ndc': package_ndc, 'description': description, 'marketing_start_date': marketing_start_date, 'marketing_end_date': marketing_end_date, 'sample': sample}
            rows.append(row)

df = pd.DataFrame(rows)

# %%
df
# Out:
#        product_ndc                     generic_name  \
# 0        77006-013                          ALCOHOL
# 1        77006-013                          ALCOHOL
# 2        77006-013                          ALCOHOL
# 3        77006-013                          ALCOHOL
# 4        77006-034                          Alcohol
# ...            ...                              ...
# 233290   0024-2792  sodium ferric gluconate complex
# 233291   58411-502  OCTINOXATE and TITANIUM DIOXIDE
# 233292   58411-556                 TITANIUM DIOXIDE
# 233293   58411-560                 TITANIUM DIOXIDE
# 233294   58411-565  OCTINOXATE and TITANIUM DIOXIDE
#
#                          labeler_name  \
# 0                   WeCool Toys, Inc.
# 1                   WeCool Toys, Inc.
# 2                   WeCool Toys, Inc.
# 3                   WeCool Toys, Inc.
# 4                         WeCool Toys
# ...                               ...
# 233290        sanofi-aventis U.S. LLC
# 233291  SHISEIDO AMERICAS CORPORATION
# 233292  SHISEIDO AMERICAS CORPORATION
# 233293  SHISEIDO AMERICAS CORPORATION
# 233294  SHISEIDO AMERICAS CORPORATION
#
#                                                brand_name  finished  \
# 0                Crazy Clean Hand Sanitizer - Berry Swirl      True
# 1                Crazy Clean Hand Sanitizer - Berry Swirl      True
# 2                Crazy Clean Hand Sanitizer - Berry Swirl      True
# 3                Crazy Clean Hand Sanitizer - Berry Swirl      True
# 4                   We Clean Hand Sanitizer Caramel Apple      True
# ...                                                   ...       ...
# 233290                                          Ferrlecit      True
# 233291  SHISEIDO SYNCHRO SKIN SELF-REFRESHING FOUNDATI...      True
# 233292    cle de peau BEAUTE RADIANT FLUID FOUNDATION B80      True
# 233293    cle de peau BEAUTE RADIANT FLUID FOUNDATION B90      True
# 233294  SHISEIDO SYNCHRO SKIN RADIANT LIFTING FOUNDATI...      True
#
#        listing_expiration_date       marketing_category dosage_form  \
# 0                     20231231  OTC MONOGRAPH NOT FINAL      LIQUID
# 1                     20231231  OTC MONOGRAPH NOT FINAL      LIQUID
# 2                     20231231  OTC MONOGRAPH NOT FINAL      LIQUID
# 3                     20231231  OTC MONOGRAPH NOT FINAL      LIQUID
# 4                     20231231  OTC MONOGRAPH NOT FINAL      LIQUID
# ...                        ...                      ...         ...
# 233290                20231231                      NDA   INJECTION
# 233291                20231231      OTC MONOGRAPH FINAL    EMULSION
# 233292                20231231      OTC MONOGRAPH FINAL    EMULSION
# 233293                20231231      OTC MONOGRAPH FINAL    EMULSION
# 233294                20231231      OTC MONOGRAPH FINAL    EMULSION
#
#                    product_type marketing_start_date  \
# 0                HUMAN OTC DRUG             20200330
# 1                HUMAN OTC DRUG             20200330
# 2                HUMAN OTC DRUG             20200330
# 3                HUMAN OTC DRUG             20200723
# 4                HUMAN OTC DRUG             20200626
# ...                         ...                  ...
# 233290  HUMAN PRESCRIPTION DRUG             20110301
# 233291           HUMAN OTC DRUG             20190901
# 233292           HUMAN OTC DRUG             20200701
# 233293           HUMAN OTC DRUG             20200701
# 233294           HUMAN OTC DRUG             20200920
#
#                                             product_id  \
# 0       77006-013_d5660475-f5c5-c05b-e053-2995a90a6fd4
# 1       77006-013_d5660475-f5c5-c05b-e053-2995a90a6fd4
# 2       77006-013_d5660475-f5c5-c05b-e053-2995a90a6fd4
# 3       77006-013_d5660475-f5c5-c05b-e053-2995a90a6fd4
# 4       77006-034_d567d693-9dfb-f51a-e053-2995a90a304b
# ...                                                ...
# 233290  0024-2792_c13b28ee-c828-4b06-b2f4-3817c5cf38a1
# 233291  58411-502_2ce453cc-1b14-471a-8753-5a8c64035111
# 233292  58411-556_2f2345f6-06cd-47dc-a45b-562d74786b9d
# 233293  58411-560_2f2345f6-06cd-47dc-a45b-562d74786b9d
# 233294  58411-565_35ccb0a8-bdf8-49d7-bb49-9e23f3ae1c55
#
#                                           brand_name_base   package_ndc  \
# 0                Crazy Clean Hand Sanitizer - Berry Swirl  77006-013-01
# 1                Crazy Clean Hand Sanitizer - Berry Swirl  77006-013-02
# 2                Crazy Clean Hand Sanitizer - Berry Swirl  77006-013-03
# 3                Crazy Clean Hand Sanitizer - Berry Swirl  77006-013-04
# 4                   We Clean Hand Sanitizer Caramel Apple  77006-034-01
# ...                                                   ...           ...
# 233290                                          Ferrlecit  0024-2792-10
# 233291  SHISEIDO SYNCHRO SKIN SELF-REFRESHING FOUNDATI...  58411-502-10
# 233292        cle de peau BEAUTE RADIANT FLUID FOUNDATION  58411-556-10
# 233293        cle de peau BEAUTE RADIANT FLUID FOUNDATION  58411-560-10
# 233294   SHISEIDO SYNCHRO SKIN RADIANT LIFTING FOUNDATION  58411-565-10
#
#                                               description marketing_end_date  \
# 0                        30 mL in 1 BOTTLE (77006-013-01)               None
# 1                 249 mL in 1 BOTTLE, PUMP (77006-013-02)               None
# 2                        60 mL in 1 BOTTLE (77006-013-03)               None
# 3                 975 mL in 1 BOTTLE, PUMP (77006-013-04)               None
# 4                 250 mL in 1 BOTTLE, PUMP (77006-034-01)               None
# ...                                                   ...                ...
# 233290  10 VIAL, SINGLE-USE in 1 CARTON (0024-2792-10)...               None
# 233291  1 BOTTLE in 1 CARTON (58411-502-10)  / 30 mL i...               None
# 233292  1 BOTTLE in 1 CARTON (58411-556-10)  / 35 mL i...               None
# 233293  1 BOTTLE in 1 CARTON (58411-560-10)  / 35 mL i...               None
# 233294  1 BOTTLE in 1 CARTON (58411-565-10)  / 30 mL i...               None
#
#        sample
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ...       ...
# 233290  False
# 233291  False
# 233292  False
# 233293  False
# 233294  False
#
# [233295 rows x 16 columns]

# %%
df.shape
# Out:
# (233295, 16)

# %%
df.columns
# Out:
# Index(['product_ndc', 'generic_name', 'labeler_name', 'brand_name', 'finished',
#        'listing_expiration_date', 'marketing_category', 'dosage_form',
#        'product_type', 'marketing_start_date', 'product_id', 'brand_name_base',
#        'package_ndc', 'description', 'marketing_end_date', 'sample'],
#       dtype='object')

# %%
df['package_ndc'] = df['package_ndc'].astype('string')

# %%
df.dtypes
# Out:
# product_ndc                object
# generic_name               object
# labeler_name               object
# brand_name                 object
# finished                     bool
# listing_expiration_date    object
# marketing_category         object
# dosage_form                object
# product_type               object
# marketing_start_date       object
# product_id                 object
# brand_name_base            object
# package_ndc                string
# description                object
# marketing_end_date         object
# sample                     object
# dtype: object

# %% [markdown]
# ## Get Product Ids

# %%
# server = ''
# database = ''
# username = ''
# password = ''
# driver= '{ODBC Driver 13 for SQL Server}'
# con = 'Yes'

# ## Start Connection
# conn = pyodbc.connect('DRIVER='+driver+';SERVER='+server+';PORT=1433;DATABASE='+database+';UID='+username+';PWD='+ password+'; MARS_Connection=' + con)
# cursor = conn.cursor()

# %%
# Define the query
query = 'SELECT Productid, Categoryid, Manufacturerid, Name, Description, SKU FROM Product Where producttypeid=2 and isactive=1 and len(sku)=11'

# Execute the query and save the results to a DataFrame
product_df = pd.read_sql_query(query, conn)

# Close the connection
conn.close()

# Print the first few rows of the DataFrame
print(product_df.head())
# Out:
# C:\Users\Alonso\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    Productid  Categoryid  Manufacturerid                         Name  \
# 0    1262655        1985              17  Cyclogyl 0.5% 15Ml Soln<Usa
# 1    1262657        1985              17     Cyclogyl 1% 2Ml Soln<Usa
# 2    1262658        1985              17     Cyclogyl 1% 5Ml Soln<Usa
# 3    1262659        1985              17        Cyclogyl 2% 15Ml Soln
# 4    1262660        1985              17     Cyclogyl 2% 2Ml Soln<Usa
#
#                    Description          SKU
# 0  Cyclogyl 0.5% 15Ml Soln<Usa  00065039515
# 1     Cyclogyl 1% 2Ml Soln<Usa  00065039602
# 2     Cyclogyl 1% 5Ml Soln<Usa  00065039605
# 3        Cyclogyl 2% 15Ml Soln  00065039715
# 4     Cyclogyl 2% 2Ml Soln<Usa  00065039702

# %%
product_df.shape
# Out:
# (157383, 6)

# %%
lengths = df['package_ndc'].str.len()
lengths.unique()
# Out:
# <IntegerArray>
# [12, 2]
# Length: 2, dtype: Int64

# %%
df[df['package_ndc'].str.len() == 2]
# Out:
#       product_ndc generic_name      labeler_name brand_name  finished  \
# 96090  53209-2000      aspirin  Morning Stat OTC       None     False
#
#       listing_expiration_date           marketing_category  \
# 96090                20171231  DRUG FOR FURTHER PROCESSING
#
#                          dosage_form     product_type marketing_start_date  \
# 96090  TABLET, ORALLY DISINTEGRATING  BULK INGREDIENT            12-JUL-12
#
#                                             product_id brand_name_base  \
# 96090  53209-2000_13fe8ca9-975f-4f3b-9eca-67f59350d60f            None
#
#       package_ndc          description marketing_end_date sample
# 96090          02  50 mg in 1 BOX (02)               None   None

# %%
# Delete rows where length of 'package_ndc' equals 2 nad Check Lengths Again
df = df[~(df['package_ndc'].str.len() == 2)]
lengths = df['package_ndc'].str.len()
lengths.unique()
# Out:
# <IntegerArray>
# [12]
# Length: 1, dtype: Int64

# %%
# Split the 'package_ndc' column into three parts using the '-' separator
parts = df['package_ndc'].str.split('-')

# Pad the first part with zeros to make it 5 digits long
parts = parts.apply(lambda x: [x[0].zfill(5), x[1], x[2]])

# Pad the second part with zeros to make it 4 digits long
parts = parts.apply(lambda x: [x[0], x[1].zfill(4), x[2]])

# Pad the third part with zeros to make it 2 digits long
parts = parts.apply(lambda x: [x[0], x[1], x[2].zfill(2)])

# Join the parts back together using the '-' separator
df['ndc11'] = parts.str.join('')
# Out:
# C:\Users\Alonso\AppData\Local\Temp\ipykernel_18912\268873611.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ndc11'] = parts.str.join('')

# %%
df['ndc11']
# Out:
# 0         77006001301
# 1         77006001302
# 2         77006001303
# 3         77006001304
# 4         77006003401
#              ...
# 233290    00024279210
# 233291    58411050210
# 233292    58411055610
# 233293    58411056010
# 233294    58411056510
# Name: ndc11, Length: 233294, dtype: object

# %%
lengths = df['ndc11'].str.len()
lengths.unique()
# Out:
# array([11], dtype=int64)

# %%
# Merge the two dataframes on column 'A'
merged_df = pd.merge(df, product_df, left_on='ndc11', right_on='SKU', how='left')
merged_df.shape
# Out:
# (233294, 23)

# %%
merged_df.head(30)
# Out:
#    product_ndc                 generic_name  \
# 0    77006-013                      ALCOHOL
# 1    77006-013                      ALCOHOL
# 2    77006-013                      ALCOHOL
# 3    77006-013                      ALCOHOL
# 4    77006-034                      Alcohol
# 5    77027-112                      ALCOHOL
# 6   77049-0012       niacinamide, adenosine
# 7    77052-010               Hydrocortisone
# 8    77052-010               Hydrocortisone
# 9    77071-006        BENZALKONIUM CHLORIDE
# 10   0615-8354                  Gemfibrozil
# 11   77093-222           IPA Hand Sanitizer
# 12   77093-222           IPA Hand Sanitizer
# 13   77093-222           IPA Hand Sanitizer
# 14  77130-0002  sodium chlorite, citric cid
# 15   77133-001                      ALCOHOL
# 16   77133-001                      ALCOHOL
# 17   77133-001                      ALCOHOL
# 18   77175-005              Ethanol alcohol
# 19   77175-008            ALCOHOL (Ethanol)
# 20   0615-8359                   Paroxetine
# 21   77251-002  Disinfectant Cleaning Wipes
# 22   77251-002  Disinfectant Cleaning Wipes
# 23   77251-002  Disinfectant Cleaning Wipes
# 24   77251-002  Disinfectant Cleaning Wipes
# 25   77267-004                Ethyl Alcohol
# 26   77267-004                Ethyl Alcohol
# 27   77267-004                Ethyl Alcohol
# 28   77267-004                Ethyl Alcohol
# 29   77267-004                Ethyl Alcohol
#
#                                   labeler_name  \
# 0                            WeCool Toys, Inc.
# 1                            WeCool Toys, Inc.
# 2                            WeCool Toys, Inc.
# 3                            WeCool Toys, Inc.
# 4                                  WeCool Toys
# 5         GUANGZHOU ZUOFUN COSMETICS CO., LTD.
# 6                            Interkos Co.,Ltd.
# 7                            Derm Ventures LLC
# 8                            Derm Ventures LLC
# 9                      Dalrada Health Products
# 10  NCS HealthCare of KY, LLC dba Vangard Labs
# 11                          Vincit Zee Company
# 12                          Vincit Zee Company
# 13                          Vincit Zee Company
# 14                         Sejin E&P Co., Ltd.
# 15                               ALCOVE BRANDS
# 16                               ALCOVE BRANDS
# 17                               ALCOVE BRANDS
# 18                                      TenSan
# 19                                      TenSan
# 20  NCS HealthCare of KY, LLC dba Vangard Labs
# 21                 QUIMICA ROSMAR S.A. DE C.V.
# 22                 QUIMICA ROSMAR S.A. DE C.V.
# 23                 QUIMICA ROSMAR S.A. DE C.V.
# 24                 QUIMICA ROSMAR S.A. DE C.V.
# 25       Ningbo Riway Daily Commodity Co., Ltd
# 26       Ningbo Riway Daily Commodity Co., Ltd
# 27       Ningbo Riway Daily Commodity Co., Ltd
# 28       Ningbo Riway Daily Commodity Co., Ltd
# 29       Ningbo Riway Daily Commodity Co., Ltd
#
#                                   brand_name  finished  \
# 0   Crazy Clean Hand Sanitizer - Berry Swirl      True
# 1   Crazy Clean Hand Sanitizer - Berry Swirl      True
# 2   Crazy Clean Hand Sanitizer - Berry Swirl      True
# 3   Crazy Clean Hand Sanitizer - Berry Swirl      True
# 4      We Clean Hand Sanitizer Caramel Apple      True
# 5              Anti-Bacterial Hand Sanitizer      True
# 6         The Fact Natural SFN 18 Skin Toner      True
# 7                                  Ala-Scalp      True
# 8                                  Ala-Scalp      True
# 9     glanHealth Hand Sanitizer Professional      True
# 10                               Gemfibrozil      True
# 11                                      LS32      True
# 12                                      LS32      True
# 13                                      LS32      True
# 14                                     AV100      True
# 15                               Fight wipes      True
# 16                               Fight wipes      True
# 17                               Fight wipes      True
# 18                     Hand Sanitizer Liquid      True
# 19                        Hand Sanitizer Gel      True
# 20                                Paroxetine      True
# 21                             Sanidry Wipes      True
# 22                             Sanidry Wipes      True
# 23                             Sanidry Wipes      True
# 24                             Sanidry Wipes      True
# 25         Anti-Bacterial Hand Sanitizer Gel      True
# 26         Anti-Bacterial Hand Sanitizer Gel      True
# 27         Anti-Bacterial Hand Sanitizer Gel      True
# 28         Anti-Bacterial Hand Sanitizer Gel      True
# 29         Anti-Bacterial Hand Sanitizer Gel      True
#
#    listing_expiration_date       marketing_category          dosage_form  \
# 0                 20231231  OTC MONOGRAPH NOT FINAL               LIQUID
# 1                 20231231  OTC MONOGRAPH NOT FINAL               LIQUID
# 2                 20231231  OTC MONOGRAPH NOT FINAL               LIQUID
# 3                 20231231  OTC MONOGRAPH NOT FINAL               LIQUID
# 4                 20231231  OTC MONOGRAPH NOT FINAL               LIQUID
# 5                 20231231  OTC MONOGRAPH NOT FINAL                  GEL
# 6                 20231231    UNAPPROVED DRUG OTHER               LIQUID
# 7                 20241231                     ANDA               LOTION
# 8                 20241231                     ANDA               LOTION
# 9                 20231231  OTC MONOGRAPH NOT FINAL                 SOAP
# 10                20231231                     ANDA  TABLET, FILM COATED
# 11                20231231  OTC MONOGRAPH NOT FINAL               LIQUID
# 12                20231231  OTC MONOGRAPH NOT FINAL               LIQUID
# 13                20231231  OTC MONOGRAPH NOT FINAL               LIQUID
# 14                20231231    UNAPPROVED DRUG OTHER               POWDER
# 15                20241231  OTC MONOGRAPH NOT FINAL                CLOTH
# 16                20241231  OTC MONOGRAPH NOT FINAL                CLOTH
# 17                20241231  OTC MONOGRAPH NOT FINAL                CLOTH
# 18                    None  OTC MONOGRAPH NOT FINAL               LIQUID
# 19                    None  OTC MONOGRAPH NOT FINAL                  GEL
# 20                20231231                     ANDA  TABLET, FILM COATED
# 21                20231231  OTC MONOGRAPH NOT FINAL                CLOTH
# 22                20231231  OTC MONOGRAPH NOT FINAL                CLOTH
# 23                20231231  OTC MONOGRAPH NOT FINAL                CLOTH
# 24                20231231  OTC MONOGRAPH NOT FINAL                CLOTH
# 25                20231231  OTC MONOGRAPH NOT FINAL                  GEL
# 26                20231231  OTC MONOGRAPH NOT FINAL                  GEL
# 27                20231231  OTC MONOGRAPH NOT FINAL                  GEL
# 28                20231231  OTC MONOGRAPH NOT FINAL                  GEL
# 29                20231231  OTC MONOGRAPH NOT FINAL                  GEL
#
#                product_type marketing_start_date  ...  \
# 0            HUMAN OTC DRUG             20200330  ...
# 1            HUMAN OTC DRUG             20200330  ...
# 2            HUMAN OTC DRUG             20200330  ...
# 3            HUMAN OTC DRUG             20200723  ...
# 4            HUMAN OTC DRUG             20200626  ...
# 5            HUMAN OTC DRUG             20201221  ...
# 6            HUMAN OTC DRUG             20220121  ...
# 7   HUMAN PRESCRIPTION DRUG             20210101  ...
# 8   HUMAN PRESCRIPTION DRUG             20200724  ...
# 9            HUMAN OTC DRUG             20200101  ...
# 10  HUMAN PRESCRIPTION DRUG             20201110  ...
# 11           HUMAN OTC DRUG             20200519  ...
# 12           HUMAN OTC DRUG             20200519  ...
# 13           HUMAN OTC DRUG             20200519  ...
# 14           HUMAN OTC DRUG             20200502  ...
# 15           HUMAN OTC DRUG             20201224  ...
# 16           HUMAN OTC DRUG             20201224  ...
# 17           HUMAN OTC DRUG             20201224  ...
# 18           HUMAN OTC DRUG             20200501  ...
# 19           HUMAN OTC DRUG             20200818  ...
# 20  HUMAN PRESCRIPTION DRUG             20201111  ...
# 21           HUMAN OTC DRUG             20200528  ...
# 22           HUMAN OTC DRUG             20200528  ...
# 23           HUMAN OTC DRUG             20200528  ...
# 24           HUMAN OTC DRUG             20200528  ...
# 25           HUMAN OTC DRUG             20200523  ...
# 26           HUMAN OTC DRUG             20200523  ...
# 27           HUMAN OTC DRUG             20200523  ...
# 28           HUMAN OTC DRUG             20200523  ...
# 29           HUMAN OTC DRUG             20200523  ...
#
#                                           description marketing_end_date  \
# 0                    30 mL in 1 BOTTLE (77006-013-01)               None
# 1             249 mL in 1 BOTTLE, PUMP (77006-013-02)               None
# 2                    60 mL in 1 BOTTLE (77006-013-03)               None
# 3             975 mL in 1 BOTTLE, PUMP (77006-013-04)               None
# 4             250 mL in 1 BOTTLE, PUMP (77006-034-01)               None
# 5           60 mL in 1 BOTTLE, PLASTIC (77027-112-01)               None
# 6                   150 mL in 1 BOTTLE (77049-0012-1)               None
# 7   1 BOTTLE, WITH APPLICATOR in 1 BOX (77052-010-...               None
# 8   1 BOTTLE, WITH APPLICATOR in 1 BOX (77052-010-...               None
# 9                     1200 mL in 1 BAG (77071-006-00)               None
# 10  30 TABLET, FILM COATED in 1 BLISTER PACK (0615...               None
# 11      236.59 mL in 1 BOTTLE, PLASTIC (77093-222-01)               None
# 12      473.18 mL in 1 BOTTLE, PLASTIC (77093-222-02)               None
# 13        3785 mL in 1 BOTTLE, PLASTIC (77093-222-03)               None
# 14                    4 g in 1 PACKAGE (77130-0002-1)               None
# 15  20 PATCH in 1 BAG (77133-001-01)  / 4 mL in 1 ...               None
# 16  50 PATCH in 1 BAG (77133-001-02)  / 4 mL in 1 ...               None
# 17  50 PACKET in 1 BOX (77133-001-03)  / 1 PATCH i...               None
# 18                    1022 L in 1 TANK (77175-005-02)           20230401
# 19                    1022 L in 1 TANK (77175-008-01)           20230818
# 20  30 TABLET, FILM COATED in 1 BLISTER PACK (0615...               None
# 21              300 CLOTH in 1 PACKAGE (77251-002-01)               None
# 22             1200 CLOTH in 1 PACKAGE (77251-002-02)               None
# 23                   40 CLOTH in 1 BOX (77251-002-03)               None
# 24                  100 CLOTH in 1 BAG (77251-002-04)               None
# 25                   30 mL in 1 BOTTLE (77267-004-01)               None
# 26                   60 mL in 1 BOTTLE (77267-004-02)               None
# 27                  100 mL in 1 BOTTLE (77267-004-03)               None
# 28                  500 mL in 1 BOTTLE (77267-004-04)               None
# 29                 1000 mL in 1 BOTTLE (77267-004-05)               None
#
#    sample        ndc11 Productid Categoryid Manufacturerid  Name  Description  \
# 0   False  77006001301       NaN        NaN            NaN   NaN          NaN
# 1   False  77006001302       NaN        NaN            NaN   NaN          NaN
# 2   False  77006001303       NaN        NaN            NaN   NaN          NaN
# 3   False  77006001304       NaN        NaN            NaN   NaN          NaN
# 4   False  77006003401       NaN        NaN            NaN   NaN          NaN
# 5   False  77027011201       NaN        NaN            NaN   NaN          NaN
# 6   False  77049001201       NaN        NaN            NaN   NaN          NaN
# 7   False  77052001001       NaN        NaN            NaN   NaN          NaN
# 8   False  77052001002       NaN        NaN            NaN   NaN          NaN
# 9   False  77071000600       NaN        NaN            NaN   NaN          NaN
# 10  False  00615835439       NaN        NaN            NaN   NaN          NaN
# 11  False  77093022201       NaN        NaN            NaN   NaN          NaN
# 12  False  77093022202       NaN        NaN            NaN   NaN          NaN
# 13  False  77093022203       NaN        NaN            NaN   NaN          NaN
# 14  False  77130000201       NaN        NaN            NaN   NaN          NaN
# 15  False  77133000101       NaN        NaN            NaN   NaN          NaN
# 16  False  77133000102       NaN        NaN            NaN   NaN          NaN
# 17  False  77133000103       NaN        NaN            NaN   NaN          NaN
# 18  False  77175000502       NaN        NaN            NaN   NaN          NaN
# 19  False  77175000801       NaN        NaN            NaN   NaN          NaN
# 20  False  00615835939       NaN        NaN            NaN   NaN          NaN
# 21  False  77251000201       NaN        NaN            NaN   NaN          NaN
# 22  False  77251000202       NaN        NaN            NaN   NaN          NaN
# 23  False  77251000203       NaN        NaN            NaN   NaN          NaN
# 24  False  77251000204       NaN        NaN            NaN   NaN          NaN
# 25  False  77267000401       NaN        NaN            NaN   NaN          NaN
# 26  False  77267000402       NaN        NaN            NaN   NaN          NaN
# 27  False  77267000403       NaN        NaN            NaN   NaN          NaN
# 28  False  77267000404       NaN        NaN            NaN   NaN          NaN
# 29  False  77267000405       NaN        NaN            NaN   NaN          NaN
#
#     SKU
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 12  NaN
# 13  NaN
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN
# 18  NaN
# 19  NaN
# 20  NaN
# 21  NaN
# 22  NaN
# 23  NaN
# 24  NaN
# 25  NaN
# 26  NaN
# 27  NaN
# 28  NaN
# 29  NaN
#
# [30 rows x 23 columns]

# %%
merged_df['Productid'].notnull().sum()
# Out:
# 50225

# %%
merged_df[merged_df['Productid'].notnull()]
# Out:
#        product_ndc                                       generic_name  \
# 125      0065-0395                       cyclopentolate hydrochloride
# 151      78206-113                                 MOMETASONE FUROATE
# 153      78206-126  mometasone furoate and formoterol fumarate dih...
# 154      78206-126  mometasone furoate and formoterol fumarate dih...
# 157      78206-138                                  Ganirelix Acetate
# ...            ...                                                ...
# 233252   0268-6649                                      Rough Pigweed
# 233263   0268-6678                                        White Alder
# 233264   58394-634                coagulation factor ix (recombinant)
# 233265   58406-445                                         etanercept
# 233289   0024-2792                    sodium ferric gluconate complex
#
#                                              labeler_name  \
# 125                              Alcon Laboratories, Inc.
# 151                                           Organon LLC
# 153                                           Organon LLC
# 154                                           Organon LLC
# 157                                           Organon LLC
# ...                                                   ...
# 233252                                   ALK-Abello, Inc.
# 233263                                   ALK-Abello, Inc.
# 233264  Wyeth BioPharma Division of Wyeth Pharmaceutic...
# 233265                                Immunex Corporation
# 233289                            sanofi-aventis U.S. LLC
#
#                             brand_name  finished listing_expiration_date  \
# 125                           Cyclogyl      True                20231231
# 151                        ASMANEX HFA      True                20231231
# 153                             Dulera      True                20231231
# 154                             Dulera      True                20231231
# 157                  Ganirelix Acetate      True                20231231
# ...                                ...       ...                     ...
# 233252   AMARANTHUS RETROFLEXUS POLLEN      True                20231231
# 233263  ALNUS INCANA SSP RUGOSA POLLEN      True                20231231
# 233264                         BeneFIX      True                20241231
# 233265                          ENBREL      True                20231231
# 233289                       Ferrlecit      True                20231231
#
#        marketing_category          dosage_form                 product_type  \
# 125                  ANDA      SOLUTION/ DROPS      HUMAN PRESCRIPTION DRUG
# 151                   NDA              AEROSOL      HUMAN PRESCRIPTION DRUG
# 153                   NDA              AEROSOL      HUMAN PRESCRIPTION DRUG
# 154                   NDA              AEROSOL      HUMAN PRESCRIPTION DRUG
# 157                   NDA  INJECTION, SOLUTION      HUMAN PRESCRIPTION DRUG
# ...                   ...                  ...                          ...
# 233252                BLA  INJECTION, SOLUTION  NON-STANDARDIZED ALLERGENIC
# 233263                BLA  INJECTION, SOLUTION  NON-STANDARDIZED ALLERGENIC
# 233264                BLA                  KIT            PLASMA DERIVATIVE
# 233265                BLA             SOLUTION      HUMAN PRESCRIPTION DRUG
# 233289                NDA            INJECTION      HUMAN PRESCRIPTION DRUG
#
#        marketing_start_date  ...  \
# 125                19751015  ...
# 151                20210601  ...
# 153                20210601  ...
# 154                20210601  ...
# 157                20210601  ...
# ...                     ...  ...
# 233252             19650101  ...
# 233263             19650101  ...
# 233264             19970201  ...
# 233265             20051110  ...
# 233289             20110301  ...
#
#                                               description marketing_end_date  \
# 125     1 BOTTLE, PLASTIC in 1 CARTON (0065-0395-15)  ...               None
# 151     1 CANISTER in 1 CARTON (78206-113-01)  / 120 A...               None
# 153     1 CANISTER in 1 CARTON (78206-126-01)  / 120 A...               None
# 154     1 CANISTER in 1 CARTON (78206-126-02)  / 60 AE...               None
# 157     1 BLISTER PACK in 1 CARTON (78206-138-01)  / 1...               None
# ...                                                   ...                ...
# 233252          5 mL in 1 VIAL, MULTI-DOSE (0268-6649-06)               None
# 233263          5 mL in 1 VIAL, MULTI-DOSE (0268-6678-05)               None
# 233264  1 KIT in 1 CARTON (58394-634-03)  *  5 mL in 1...               None
# 233265  4 SYRINGE in 1 CARTON (58406-445-04)  / 1 mL i...               None
# 233289  10 VIAL, SINGLE-USE in 1 CARTON (0024-2792-10)...               None
#
#        sample        ndc11  Productid Categoryid Manufacturerid  \
# 125     False  00065039515  1262655.0     1985.0           17.0
# 151     False  78206011301  5003255.0     1606.0         3166.0
# 153     False  78206012601  5001603.0     1606.0         3166.0
# 154     False  78206012602  4987039.0     1606.0         3166.0
# 157     False  78206013801  5003209.0     1970.0         3166.0
# ...       ...          ...        ...        ...            ...
# 233252  False  00268664906  2826852.0     1903.0         4148.0
# 233263  False  00268667805  2863953.0     1903.0         4148.0
# 233264  False  58394063403  2922366.0     2058.0         3192.0
# 233265  False  58406044504  2978018.0     1910.0         2365.0
# 233289  False  00024279210  2847339.0     1879.0          333.0
#
#                                                      Name  \
# 125                           Cyclogyl 0.5% 15Ml Soln<Usa
# 151                       Asmanex Hfa, Mometasone Furoate
# 153                            Dulera Mdi 200MCG 120 Dose
# 154     Dulera, Mometasone Furoate And Formoterol Fuma...
# 157                                     Ganirelix Acetate
# ...                                                   ...
# 233252       Rough Pigweed, Amaranthus Retroflexus Pollen
# 233263        White Alder, Alnus Incana Ssp Rugosa Pollen
# 233264                               Benefix 500 Unit Kit
# 233265                             Enbrel Surclk 50MG /ML
# 233289         Sodium Ferric Gluconate Complex, Ferrlecit
#
#                                               Description          SKU
# 125                           Cyclogyl 0.5% 15Ml Soln<Usa  00065039515
# 151                                1 canister in 1 carton  78206011301
# 153                            Dulera Mdi 200MCG 120 Dose  78206012601
# 154     Dulera, Mometasone Furoate And Formoterol Fuma...  78206012602
# 157     1 blister pack in 1 carton > 1 syringe, glass ...  78206013801
# ...                                                   ...          ...
# 233252                         5 Ml In 1 Vial, Multi-Dose  00268664906
# 233263                         5 Ml In 1 Vial, Multi-Dose  00268667805
# 233264                                      Qty 1, KIT, 1  58394063403
# 233265                             Enbrel Surclk 50MG /ML  58406044504
# 233289                                    Qty 10, VIAL, 5  00024279210
#
# [50225 rows x 23 columns]

# %% [markdown]
# ## JSON to Package Data Frame

# %%
# Create a Dartaframe
package_df = pd.DataFrame(columns=['product_ndc', 'package_ndc', 'description', 'marketing_start_date', 'marketing_end_date', 'sample'])

# %%
rows = []
for product in data:
    product_ndc = product.get('product_ndc', None)
    packaging = product.get('packaging', [])
    for package in packaging:
        package_ndc = package.get('package_ndc', None)
        description = package.get('description', None)
        marketing_start_date = package.get('marketing_start_date', None)
        marketing_end_date = package.get('marketing_end_date', None)
        sample = package.get('sample', None)
        if package_ndc is not None and description is not None:
            row = {'product_ndc': product_ndc, 'package_ndc': package_ndc, 'description': description}
            rows.append(row)
package_df = pd.DataFrame(rows)
package_df
# Out:
#        product_ndc   package_ndc  \
# 0        77006-013  77006-013-01
# 1        77006-013  77006-013-02
# 2        77006-013  77006-013-03
# 3        77006-013  77006-013-04
# 4        77006-034  77006-034-01
# ...            ...           ...
# 233290   0024-2792  0024-2792-10
# 233291   58411-502  58411-502-10
# 233292   58411-556  58411-556-10
# 233293   58411-560  58411-560-10
# 233294   58411-565  58411-565-10
#
#                                               description
# 0                        30 mL in 1 BOTTLE (77006-013-01)
# 1                 249 mL in 1 BOTTLE, PUMP (77006-013-02)
# 2                        60 mL in 1 BOTTLE (77006-013-03)
# 3                 975 mL in 1 BOTTLE, PUMP (77006-013-04)
# 4                 250 mL in 1 BOTTLE, PUMP (77006-034-01)
# ...                                                   ...
# 233290  10 VIAL, SINGLE-USE in 1 CARTON (0024-2792-10)...
# 233291  1 BOTTLE in 1 CARTON (58411-502-10)  / 30 mL i...
# 233292  1 BOTTLE in 1 CARTON (58411-556-10)  / 35 mL i...
# 233293  1 BOTTLE in 1 CARTON (58411-560-10)  / 35 mL i...
# 233294  1 BOTTLE in 1 CARTON (58411-565-10)  / 30 mL i...
#
# [233295 rows x 3 columns]

# %% [markdown]
# ## JSON to Ingredients Data Frame

# %%
# Create a Dartaframe
ingredients_df = pd.DataFrame(columns=['product_ndc', 'name', 'strength'])

# %%
rows = []
for product in data:
    product_ndc = product.get('product_ndc', None)
    active_ingredients = product.get('active_ingredients', [])
    for ingredients in active_ingredients:
        name = ingredients.get('name', None)
        strength = ingredients.get('strength', None)
        if name is not None and strength is not None:
            row = {'product_ndc': product_ndc, 'name': name, 'strength': strength}
            rows.append(row)

ingredients_df = pd.DataFrame(rows)
ingredients_df
# Out:
#        product_ndc              name        strength
# 0        77006-013           ALCOHOL   58.36 g/100mL
# 1        77006-034           ALCOHOL   58.36 g/100mL
# 2        77027-112           ALCOHOL     75 mL/100mL
# 3       77049-0012         ADENOSINE     .04 g/100mL
# 4       77049-0012       NIACINAMIDE       2 g/100mL
# ...            ...               ...             ...
# 208286   58411-502  TITANIUM DIOXIDE    2.001 g/30mL
# 208287   58411-556  TITANIUM DIOXIDE  2.72118 g/35mL
# 208288   58411-560  TITANIUM DIOXIDE  2.72118 g/35mL
# 208289   58411-565        OCTINOXATE    2.484 g/30mL
# 208290   58411-565  TITANIUM DIOXIDE      .36 g/30mL
#
# [208291 rows x 3 columns]

# %%
ingredients_df.shape
# Out:
# (208291, 3)

# %%
# create a new dataframe with unique ids for each combination of 'name' and 'strength'
id_df = ingredients_df[['name', 'strength']].drop_duplicates().reset_index(drop=True).reset_index()
id_df.columns = ['ingredient_id', 'name', 'strength']

# merge the new dataframe with the original dataframe
ingredients_df = ingredients_df.merge(id_df, on=['name', 'strength'])

# print the result
print(ingredients_df)
# Out:
#        product_ndc         name       strength  ingredient_id
# 0        77006-013      ALCOHOL  58.36 g/100mL              0
# 1        77006-034      ALCOHOL  58.36 g/100mL              0
# 2        77006-020      ALCOHOL  58.36 g/100mL              0
# 3        77006-030      ALCOHOL  58.36 g/100mL              0
# 4        77006-060      ALCOHOL  58.36 g/100mL              0
# ...            ...          ...            ...            ...
# 208286   58411-365   HOMOSALATE    1500 mg/15g          49874
# 208287   58411-365   OCTINOXATE     735 mg/15g          49875
# 208288   58411-365   OCTISALATE     750 mg/15g          49876
# 208289   58411-365  OCTOCRYLENE     750 mg/15g          49877
# 208290   58411-365   OXYBENZONE     450 mg/15g          49878
#
# [208291 rows x 4 columns]

# %%
ingredients_df.head(50)
# Out:
#    product_ndc     name       strength  ingredient_id
# 0    77006-013  ALCOHOL  58.36 g/100mL              0
# 1    77006-034  ALCOHOL  58.36 g/100mL              0
# 2    77006-020  ALCOHOL  58.36 g/100mL              0
# 3    77006-030  ALCOHOL  58.36 g/100mL              0
# 4    77006-060  ALCOHOL  58.36 g/100mL              0
# 5    77006-006  ALCOHOL  58.36 g/100mL              0
# 6    77006-007  ALCOHOL  58.36 g/100mL              0
# 7    77006-033  ALCOHOL  58.36 g/100mL              0
# 8    77006-061  ALCOHOL  58.36 g/100mL              0
# 9    77006-003  ALCOHOL  58.36 g/100mL              0
# 10   77006-035  ALCOHOL  58.36 g/100mL              0
# 11   77006-001  ALCOHOL  58.36 g/100mL              0
# 12   77006-012  ALCOHOL  58.36 g/100mL              0
# 13   77006-031  ALCOHOL  58.36 g/100mL              0
# 14   77006-005  ALCOHOL  58.36 g/100mL              0
# 15   77006-032  ALCOHOL  58.36 g/100mL              0
# 16   77027-112  ALCOHOL    75 mL/100mL              1
# 17   77267-004  ALCOHOL    75 mL/100mL              1
# 18   77578-001  ALCOHOL    75 mL/100mL              1
# 19   78323-103  ALCOHOL    75 mL/100mL              1
# 20   78691-200  ALCOHOL    75 mL/100mL              1
# 21   78755-001  ALCOHOL    75 mL/100mL              1
# 22   78868-003  ALCOHOL    75 mL/100mL              1
# 23   79587-100  ALCOHOL    75 mL/100mL              1
# 24   79624-002  ALCOHOL    75 mL/100mL              1
# 25   80204-008  ALCOHOL    75 mL/100mL              1
# 26   80204-023  ALCOHOL    75 mL/100mL              1
# 27   80204-033  ALCOHOL    75 mL/100mL              1
# 28   80204-044  ALCOHOL    75 mL/100mL              1
# 29   80313-008  ALCOHOL    75 mL/100mL              1
# 30   80552-001  ALCOHOL    75 mL/100mL              1
# 31   80948-004  ALCOHOL    75 mL/100mL              1
# 32   80948-012  ALCOHOL    75 mL/100mL              1
# 33   42509-020  ALCOHOL    75 mL/100mL              1
# 34   43473-221  ALCOHOL    75 mL/100mL              1
# 35   50157-507  ALCOHOL    75 mL/100mL              1
# 36   50157-513  ALCOHOL    75 mL/100mL              1
# 37  51531-8735  ALCOHOL    75 mL/100mL              1
# 38   51706-901  ALCOHOL    75 mL/100mL              1
# 39   52000-400  ALCOHOL    75 mL/100mL              1
# 40   52985-901  ALCOHOL    75 mL/100mL              1
# 41   54860-390  ALCOHOL    75 mL/100mL              1
# 42   54860-391  ALCOHOL    75 mL/100mL              1
# 43   56136-310  ALCOHOL    75 mL/100mL              1
# 44   58133-959  ALCOHOL    75 mL/100mL              1
# 45   58133-959  ALCOHOL    75 mL/100mL              1
# 46   58133-961  ALCOHOL    75 mL/100mL              1
# 47   58133-962  ALCOHOL    75 mL/100mL              1
# 48   58133-963  ALCOHOL    75 mL/100mL              1
# 49   70888-002  ALCOHOL    75 mL/100mL              1

# %%
# Create an ingredients table
ingredients= ingredients_df[['ingredient_id', 'name', 'strength']].drop_duplicates().reset_index(drop=True)
ingredients
# Out:
#        ingredient_id            name       strength
# 0                  0         ALCOHOL  58.36 g/100mL
# 1                  1         ALCOHOL    75 mL/100mL
# 2                  2       ADENOSINE    .04 g/100mL
# 3                  3     NIACINAMIDE      2 g/100mL
# 4                  4  HYDROCORTISONE       20 mg/mL
# ...              ...             ...            ...
# 49874          49874      HOMOSALATE    1500 mg/15g
# 49875          49875      OCTINOXATE     735 mg/15g
# 49876          49876      OCTISALATE     750 mg/15g
# 49877          49877     OCTOCRYLENE     750 mg/15g
# 49878          49878      OXYBENZONE     450 mg/15g
#
# [49879 rows x 3 columns]

# %%
# Creaate a table that links NDC to ingredients
ingredients_ndc= ingredients_df[['ingredient_id', 'product_ndc']].drop_duplicates().reset_index(drop=True)
ingredients_ndc
# Out:
#         ingredient_id product_ndc
# 0                   0   77006-013
# 1                   0   77006-034
# 2                   0   77006-020
# 3                   0   77006-030
# 4                   0   77006-060
# ...               ...         ...
# 205595          49874   58411-365
# 205596          49875   58411-365
# 205597          49876   58411-365
# 205598          49877   58411-365
# 205599          49878   58411-365
#
# [205600 rows x 2 columns]

# %% [markdown]
# ### Save DF

# %%
df.to_csv('C:/Users/Alonso/Downloads/ndc/NDC_rdb.csv', index=False)
package_df.to_csv('C:/Users/Alonso/Downloads/ndc/package_df_rdb.csv', index=False)
ingredients.to_csv('C:/Users/Alonso/Downloads/ndc/ingredients_rdb.csv', index=False)
ingredients_ndc.to_csv('C:/Users/Alonso/Downloads/ndc/ingredients_ndc_rdb.csv', index=False)
